# %%
# Import dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

#Add Citipy Imprt Citipy
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config_weather_database import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

cities
# Out:
# ['langsa',
#  'hambantota',
#  'sao joao da barra',
#  'san patricio',
#  'wanaka',
#  'hobart',
#  'labuhan',
#  'mujiayingzi',
#  'cidreira',
#  'ushuaia',
#  'pithoragarh',
#  'vaini',
#  'vila velha',
#  'rocha',
#  'mataura',
#  'nanortalik',
#  'nevesinje',
#  'gannan',
#  'chokurdakh',
#  'kapaa',
#  'taolanaro',
#  'hualmay',
#  'ekibastuz',
#  'yellowknife',
#  'hilo',
#  'bathsheba',
#  'sumbawa',
#  'albany',
#  'punta arenas',
#  'lavrentiya',
#  'kodiak',
#  'oum hadjer',
#  'carnarvon',
#  'barrow',
#  'new norfolk',
#  'rikitea',
#  'vila franca do campo',
#  'hermanus',
#  'marawi',
#  'saleaula',
#  'bluff',
#  'pangody',
#  'camacha',
#  'qurbah',
#  'majene',
#  'faanui',
#  'east london',
#  'pevek',
#  'san jose',
#  'provideniya',
#  'barentsburg',
#  'busselton',
#  'avarua',
#  'lafia',
#  'georgetown',
#  'thayetmyo',
#  'kushiro',
#  'pacific grove',
#  'husavik',
#  'ponta do sol',
#  'khatanga',
#  'atuona',
#  'whitley bay',
#  'kitimat',
#  'thinadhoo',
#  'mys shmidta',
#  'tiksi',
#  'bredasdorp',
#  'leshukonskoye',
#  'belushya guba',
#  'fortuna',
#  'batagay',
#  'faya',
#  'acapulco',
#  'yulara',
#  'cape town',
#  'gwadar',
#  'marcona',
#  'cayenne',
#  'tura',
#  'amderma',
#  'odweyne',
#  'comodoro rivadavia',
#  'shitkino',
#  'richards bay',
#  'shunyi',
#  'santa catarina de tepehuanes',
#  'attawapiskat',
#  'qaanaaq',
#  'klyuchi',
#  'vardo',
#  'guerrero negro',
#  'longyearbyen',
#  'hasaki',
#  'hudson bay',
#  'yuzhno-yeniseyskiy',
#  'vuktyl',
#  'butaritari',
#  'olafsvik',
#  'arraial do cabo',
#  'takoradi',
#  'qaqortoq',
#  'kerki',
#  'port elizabeth',
#  'katsuura',
#  'deloraine',
#  'jamestown',
#  'lensk',
#  'fairbanks',
#  'turukhansk',
#  'tasiilaq',
#  'dikson',
#  'castro',
#  'half moon bay',
#  'ilulissat',
#  'saldanha',
#  'poum',
#  'dingle',
#  'ribeira grande',
#  'zarechnyy',
#  'mount gambier',
#  'khasan',
#  'puerto ayora',
#  'constitucion',
#  'la roda',
#  'hithadhoo',
#  'geraldton',
#  'ostersund',
#  'gobabis',
#  'saint-augustin',
#  'tumannyy',
#  'nizhniy baskunchak',
#  'port moresby',
#  'paragominas',
#  'reinosa',
#  'mandalgovi',
#  'kidal',
#  'kandrian',
#  'odda',
#  'berlevag',
#  'mangai',
#  'katobu',
#  'saint george',
#  'severo-kurilsk',
#  'berdigestyakh',
#  'sulangan',
#  'bolgatanga',
#  'tsihombe',
#  'alofi',
#  'narsaq',
#  'illoqqortoormiut',
#  'san cristobal',
#  'flin flon',
#  'ketchikan',
#  'lorengau',
#  'esperance',
#  'asayita',
#  'dubai',
#  'tuktoyaktuk',
#  'nizhneyansk',
#  'mahebourg',
#  'svobodnyy',
#  'avera',
#  'filadelfia',
#  'venice',
#  'samarai',
#  'marienburg',
#  'viligili',
#  'haines junction',
#  'kaniama',
#  'necochea',
#  'seidu',
#  'xining',
#  'kununurra',
#  'pueblo nuevo',
#  'souillac',
#  'enna',
#  'tuatapere',
#  'nacogdoches',
#  'marsh harbour',
#  'bucerias',
#  'umzimvubu',
#  'aykhal',
#  'harboore',
#  'itarema',
#  'bargal',
#  'batemans bay',
#  'hofn',
#  'saint-philippe',
#  'yibin',
#  'hecun',
#  'muzhi',
#  'bengkulu',
#  'waddan',
#  'ketou',
#  'mandapam',
#  'winnemucca',
#  'muros',
#  'bethel',
#  'namibe',
#  'sitka',
#  'chuy',
#  'praia',
#  'sharlyk',
#  'arzgir',
#  'marsa matruh',
#  'traverse city',
#  'dutse',
#  'laurel',
#  'lagoa',
#  'okoneshnikovo',
#  'biak',
#  'barsovo',
#  'touros',
#  'lluta',
#  'aklavik',
#  'namatanai',
#  'kutum',
#  'kahului',
#  'black diamond',
#  'ambulu',
#  'padrauna',
#  'nanpiao',
#  'prince rupert',
#  'ponta delgada',
#  'ambilobe',
#  'kieta',
#  'college',
#  'port blair',
#  'petropavlovsk-kamchatskiy',
#  'torbay',
#  'erzin',
#  'port hardy',
#  'cardston',
#  'isla mujeres',
#  'vaitupu',
#  'gillette',
#  'clyde river',
#  'margate',
#  'prescott',
#  'tonj',
#  'lata',
#  'banda aceh',
#  'lebu',
#  'katangli',
#  'halalo',
#  'fougamou',
#  'lasa',
#  'pangnirtung',
#  'rundu',
#  'lima',
#  'koungou',
#  'michigan city',
#  'cam ranh',
#  'bilasipara',
#  'maputo',
#  'airai',
#  'calategas',
#  'norman wells',
#  'rafsanjan',
#  'caninde de sao francisco',
#  'henties bay',
#  'cherskiy',
#  'broome',
#  'chicama',
#  'saint-pierre',
#  'riberalta',
#  'kloulklubed',
#  'beloha',
#  'kasongo-lunda',
#  'uvat',
#  'lakhipur',
#  'viedma',
#  'egvekinot',
#  'kamarion',
#  'saint-joseph',
#  'taoudenni',
#  'adrar',
#  'saint-denis',
#  'santa cruz de tenerife',
#  'hun',
#  'sao filipe',
#  'harlingen',
#  'ojinaga',
#  'griffith',
#  'aitape',
#  'moussoro',
#  'krasnyy bogatyr',
#  'ancud',
#  'lakewood',
#  'along',
#  'torrijos',
#  'poso',
#  'orlik',
#  'syamzha',
#  'kostomuksha',
#  'flinders',
#  'fare',
#  'kant',
#  'port alfred',
#  'beaverlodge',
#  'erie',
#  'ahipara',
#  'yelizovo',
#  'waipawa',
#  'pisco',
#  'nanakuli',
#  'port hedland',
#  'kilindoni',
#  'hopelchen',
#  'bambous virieux',
#  'wonthaggi',
#  'ust-maya',
#  'baturaja',
#  'sioux lookout',
#  'hirna',
#  'grand river south east',
#  'chara',
#  'kamenka',
#  'youkounkoun',
#  'stepnoye',
#  'bijar',
#  'miramar',
#  'midyat',
#  'matara',
#  'saskylakh',
#  'sao joao de pirabas',
#  'brownwood',
#  'sorland',
#  'unye',
#  'killybegs',
#  'tallahassee',
#  'diego de almagro',
#  'nikolskoye',
#  'magetan',
#  'ejido',
#  'kaitangata',
#  'bykovo',
#  'parfenyevo',
#  'carnot',
#  'zlobin',
#  'bastrop',
#  'hare bay',
#  'anito',
#  'grand-santi',
#  'hai duong',
#  'isla vista',
#  'rudnya',
#  'mayo',
#  'salihorsk',
#  'pinalejo',
#  'dubbo',
#  'tabuk',
#  'palabuhanratu',
#  'havre-saint-pierre',
#  'igrim',
#  'rio gallegos',
#  'chabahar',
#  'bianzhuang',
#  'eureka',
#  'jatai',
#  'srandakan',
#  'roald',
#  'hendersonville',
#  'severomuysk',
#  'mulanje',
#  'rassvet',
#  'baruun-urt',
#  'kavieng',
#  'sechura',
#  'luau',
#  'ghanzi',
#  'wagar',
#  'sentyabrskiy',
#  'caravelas',
#  'riyadh',
#  'ust-kachka',
#  'lazaro cardenas',
#  'kruisfontein',
#  'tanete',
#  'vytegra',
#  'banes',
#  'los llanos de aridane',
#  'klaksvik',
#  'mar del plata',
#  'keita',
#  'nome',
#  'zuenoula',
#  'craig',
#  'armidale',
#  'nouadhibou',
#  'port arthur',
#  'seoul',
#  'port lincoln',
#  'upata',
#  'bonavista',
#  'palmer',
#  'jumla',
#  'cocal',
#  'binabalian',
#  'yangjiang',
#  'raudeberg',
#  'laguna',
#  'gat',
#  'bagacay',
#  'soimi',
#  'itaituba',
#  'umm kaddadah',
#  'thompson',
#  'nakhon thai',
#  'sigulda',
#  'cockburn town',
#  'atbasar',
#  'nishihara',
#  'shubarshi',
#  'upernavik',
#  'rawannawi',
#  'shimoda',
#  'tilichiki',
#  'kuching',
#  'salinopolis',
#  'uchiza',
#  'atar',
#  'deputatskiy',
#  'imbituba',
#  'miri',
#  'kerouane',
#  'kocevje',
#  'sao raimundo das mangabeiras',
#  'sorong',
#  'wukari',
#  'usinsk',
#  'soure',
#  'karaul',
#  'cabo san lucas',
#  'baisha',
#  'camocim',
#  'uige',
#  'coihaique',
#  'harrisonburg',
#  'san andres',
#  'lompoc',
#  'mantua',
#  'yar-sale',
#  'solnechnyy',
#  'padampur',
#  'bayangol',
#  'koshki',
#  'kembolcha',
#  'la rioja',
#  'arrecife',
#  'russell',
#  'macomb',
#  'zaysan',
#  'yunjinghong',
#  'chapais',
#  'milkovo',
#  'tarko-sale',
#  'arnes',
#  'pundaguitan',
#  'luanda',
#  'kedougou',
#  'santa fe',
#  'isangel',
#  'khorinsk',
#  'talnakh',
#  'padang',
#  'crab hill',
#  'sept-iles',
#  'mahuva',
#  'tottori',
#  'hamilton',
#  'mangan',
#  'lieksa',
#  'victoria',
#  'lucapa',
#  'bereda',
#  'rio grande',
#  'iglesias',
#  'zamora',
#  'srednekolymsk',
#  'codrington',
#  'kavaratti',
#  'walvis bay',
#  'levelland',
#  'filingue',
#  'la ronge',
#  'kathu',
#  'tsukumi',
#  'luorong',
#  'mukhen',
#  'sahuaripa',
#  'camana',
#  'aflu',
#  'moranbah',
#  'paita',
#  'nautanwa',
#  'fort nelson',
#  'sobolevo',
#  'amapa',
#  'nago',
#  'kazalinsk',
#  'broken hill',
#  'katherine',
#  'maningrida',
#  'cururupu',
#  'qingdao',
#  'dvinskoy',
#  'ranong',
#  'mirnyy',
#  'te anau',
#  'estevan',
#  'dryden',
#  'arlit',
#  'nadym',
#  'ouro preto do oeste',
#  'assiniboia',
#  'ahero',
#  'borba',
#  'vakhrushev',
#  'luderitz',
#  'san jeronimo',
#  'vanimo',
#  'vagur',
#  'sakakah',
#  'chhatak',
#  'nador',
#  'rosetta',
#  'porto nacional',
#  'manado',
#  'armacao dos buzios',
#  'saint anthony',
#  'salalah',
#  'sungai pelek',
#  'brae',
#  'dir',
#  'moose factory',
#  'barreirinhas',
#  'lugovoy',
#  'lewistown',
#  'stokmarknes',
#  'kumluca',
#  'capao bonito',
#  'vertou',
#  'yerofey pavlovich',
#  'gorontalo',
#  'makueni',
#  'indian head',
#  'mayumba',
#  'meulaboh',
#  'iqaluit',
#  'kuche',
#  'grand gaube',
#  'mogadishu',
#  'toccoa',
#  'deniliquin',
#  'kenai',
#  'rakaia',
#  'razdolnoye',
#  'kashi',
#  'ergani',
#  'shahabad',
#  'krasnyy profintern',
#  'halifax',
#  'leh',
#  'chingirlau',
#  'nemuro',
#  'nsoko',
#  'porto novo',
#  'waverley',
#  'homer',
#  'kapellen',
#  'nikki',
#  'makungu',
#  'gisors',
#  'outjo',
#  'vestbygda',
#  'zilair',
#  'pokhara',
#  'evensk',
#  'svetlogorsk',
#  'rodos',
#  'pandan',
#  'princeton',
#  'belen',
#  'yerbogachen',
#  'cabanas',
#  'taywarah',
#  'taber',
#  'makhachkala',
#  'portland',
#  'louisbourg',
#  'ushtobe',
#  'sturgeon falls',
#  'potosi',
#  'carballo',
#  'gouyave',
#  'north platte',
#  'pozo colorado',
#  'zhangye',
#  'changping',
#  'kailua',
#  'nantucket',
#  'wellington',
#  'mehamn',
#  'hovd',
#  'araouane',
#  'terme',
#  'huarmey',
#  'lao cai',
#  'iracoubo',
#  'byron bay',
#  'fort-shevchenko',
#  'nova borova',
#  'aksarka',
#  'kulunda',
#  'hluti',
#  'honiara',
#  'fernley',
#  'barcelos',
#  'vallenar',
#  'chimbarongo',
#  'la tuque',
#  'dongsheng',
#  'karlskrona',
#  'tranas',
#  'mitchell',
#  'saint-francois',
#  'kyzyl-suu',
#  'batticaloa',
#  'inuvik',
#  'sakaiminato',
#  'zychlin',
#  'mirabad',
#  'noumea',
#  'susanville',
#  'samusu',
#  'minab',
#  'coahuayana',
#  'springdale',
#  'naze',
#  'makakilo city',
#  'podujevo',
#  'abu kamal',
#  'weligama',
#  'teixoso',
#  'vostok',
#  'toamasina',
#  'saint-leu',
#  'lolua',
#  'launceston',
#  'nouakchott',
#  'kurchum',
#  'ostrovnoy',
#  'bezhetsk',
#  'shirokiy',
#  'mackay',
#  'calabar',
#  'tsabong',
#  'polovinnoye',
#  'tucurui',
#  'iquique',
#  'spencer',
#  'vaijapur',
#  'inhambane',
#  'sijunjung',
#  'lufilufi',
#  'tiznit',
#  'taganak',
#  'tha mai',
#  'ascension',
#  'grindavik',
#  'celestun',
#  'ulkan',
#  'dabat',
#  'binzhou',
#  'artvin',
#  'rungata',
#  'voskresenskoye',
#  'ialibu',
#  'gazanjyk',
#  'santa cruz del sur',
#  'kapoeta',
#  'cedar city',
#  'hailar',
#  'soyalo',
#  'warqla',
#  'janakpur road',
#  'montivilliers',
#  'popondetta',
#  'hobyo',
#  'malia',
#  'yarkovo',
#  'gurskoye',
#  'sajanan',
#  'raymond terrace',
#  'amethi',
#  'maarianhamina',
#  'wangaratta',
#  'sendai',
#  'dunedin',
#  'taga dzong',
#  'springbok',
#  'yairipok',
#  'bethanien',
#  'hervey bay',
#  'kyra',
#  'abu jubayhah',
#  'tawzar',
#  'sidi bu zayd',
#  'vung tau',
#  'dudinka',
#  'kyaukse',
#  'shieli',
#  'toftir',
#  'gazli',
#  'ajdabiya',
#  'gazni',
#  'korba',
#  'jodhpur',
#  'yumen',
#  'porto torres',
#  'ndola',
#  'bolshaya irba',
#  'staszow',
#  'san quintin',
#  'morondava',
#  'ishigaki',
#  'asau',
#  'arfara',
#  'kaoma',
#  'garhi yasin',
#  'paamiut',
#  'crixas',
#  'deer lake',
#  'balkanabat',
#  'ganzhou',
#  'westport',
#  'vangaindrano',
#  'kirakira',
#  'takefu',
#  'pudozh',
#  'bolshaya murta',
#  'cabatuan',
#  'mehran',
#  'omboue',
#  'navoi',
#  'vaitape',
#  'oyama',
#  'alihe',
#  'zhigansk',
#  'muborak',
#  'rawlins',
#  'skibbereen',
#  'bahia blanca',
#  'suntar']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print (url)

# %%
# Create an empty list to hold the weather data.

# List of city data
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]       
            
            # Append the City information into city_data list
        city_data.append({"City": city.title(), 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})
    # If an error is experienced, skip the city

    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | langsa
# Processing Record 2 of Set 1 | hambantota
# Processing Record 3 of Set 1 | sao joao da barra
# Processing Record 4 of Set 1 | san patricio
# Processing Record 5 of Set 1 | wanaka
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | labuhan
# Processing Record 8 of Set 1 | mujiayingzi
# Processing Record 9 of Set 1 | cidreira
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | pithoragarh
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | vila velha
# Processing Record 14 of Set 1 | rocha
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | nanortalik
# Processing Record 17 of Set 1 | nevesinje
# Processing Record 18 of Set 1 | gannan
# Processing Record 19 of Set 1 | chokurdakh
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | hualmay
# Processing Record 23 of Set 1 | ekibastuz
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | bathsheba
# Processing Record 27 of Set 1 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | lavrentiya
# Processing Record 31 of Set 1 | kodiak
# Processing Record 32 of Set 1 | oum hadjer
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | rikitea
# Processing Record 37 of Set 1 | vila franca do campo
# Processing Record 38 of Set 1 | hermanus
# Processing Record 39 of Set 1 | marawi
# Processing Record 40 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | pangody
# Processing Record 43 of Set 1 | camacha
# Processing Record 44 of Set 1 | qurbah
# City not found. Skipping...
# Processing Record 45 of Set 1 | majene
# Processing Record 46 of Set 1 | faanui
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | san jose
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 2 | busselton
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | lafia
# Processing Record 5 of Set 2 | georgetown
# Processing Record 6 of Set 2 | thayetmyo
# Processing Record 7 of Set 2 | kushiro
# Processing Record 8 of Set 2 | pacific grove
# Processing Record 9 of Set 2 | husavik
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | khatanga
# Processing Record 12 of Set 2 | atuona
# Processing Record 13 of Set 2 | whitley bay
# Processing Record 14 of Set 2 | kitimat
# Processing Record 15 of Set 2 | thinadhoo
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | leshukonskoye
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | fortuna
# Processing Record 22 of Set 2 | batagay
# Processing Record 23 of Set 2 | faya
# Processing Record 24 of Set 2 | acapulco
# Processing Record 25 of Set 2 | yulara
# Processing Record 26 of Set 2 | cape town
# Processing Record 27 of Set 2 | gwadar
# Processing Record 28 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 29 of Set 2 | cayenne
# Processing Record 30 of Set 2 | tura
# Processing Record 31 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 2 | odweyne
# Processing Record 33 of Set 2 | comodoro rivadavia
# Processing Record 34 of Set 2 | shitkino
# Processing Record 35 of Set 2 | richards bay
# Processing Record 36 of Set 2 | shunyi
# Processing Record 37 of Set 2 | santa catarina de tepehuanes
# Processing Record 38 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 2 | qaanaaq
# Processing Record 40 of Set 2 | klyuchi
# Processing Record 41 of Set 2 | vardo
# Processing Record 42 of Set 2 | guerrero negro
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | hasaki
# Processing Record 45 of Set 2 | hudson bay
# Processing Record 46 of Set 2 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 47 of Set 2 | vuktyl
# Processing Record 48 of Set 2 | butaritari
# Processing Record 49 of Set 2 | olafsvik
# Processing Record 50 of Set 2 | arraial do cabo
# Processing Record 1 of Set 3 | takoradi
# Processing Record 2 of Set 3 | qaqortoq
# Processing Record 3 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 4 of Set 3 | port elizabeth
# Processing Record 5 of Set 3 | katsuura
# Processing Record 6 of Set 3 | deloraine
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | lensk
# Processing Record 9 of Set 3 | fairbanks
# Processing Record 10 of Set 3 | turukhansk
# Processing Record 11 of Set 3 | tasiilaq
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | half moon bay
# Processing Record 15 of Set 3 | ilulissat
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | poum
# Processing Record 18 of Set 3 | dingle
# Processing Record 19 of Set 3 | ribeira grande
# Processing Record 20 of Set 3 | zarechnyy
# Processing Record 21 of Set 3 | mount gambier
# Processing Record 22 of Set 3 | khasan
# Processing Record 23 of Set 3 | puerto ayora
# Processing Record 24 of Set 3 | constitucion
# Processing Record 25 of Set 3 | la roda
# Processing Record 26 of Set 3 | hithadhoo
# Processing Record 27 of Set 3 | geraldton
# Processing Record 28 of Set 3 | ostersund
# Processing Record 29 of Set 3 | gobabis
# Processing Record 30 of Set 3 | saint-augustin
# Processing Record 31 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 3 | nizhniy baskunchak
# Processing Record 33 of Set 3 | port moresby
# Processing Record 34 of Set 3 | paragominas
# Processing Record 35 of Set 3 | reinosa
# Processing Record 36 of Set 3 | mandalgovi
# Processing Record 37 of Set 3 | kidal
# Processing Record 38 of Set 3 | kandrian
# Processing Record 39 of Set 3 | odda
# Processing Record 40 of Set 3 | berlevag
# Processing Record 41 of Set 3 | mangai
# Processing Record 42 of Set 3 | katobu
# Processing Record 43 of Set 3 | saint george
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | berdigestyakh
# Processing Record 46 of Set 3 | sulangan
# Processing Record 47 of Set 3 | bolgatanga
# Processing Record 48 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 3 | alofi
# Processing Record 50 of Set 3 | narsaq
# Processing Record 1 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 4 | san cristobal
# Processing Record 3 of Set 4 | flin flon
# Processing Record 4 of Set 4 | ketchikan
# Processing Record 5 of Set 4 | lorengau
# Processing Record 6 of Set 4 | esperance
# Processing Record 7 of Set 4 | asayita
# City not found. Skipping...
# Processing Record 8 of Set 4 | dubai
# Processing Record 9 of Set 4 | tuktoyaktuk
# Processing Record 10 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 4 | mahebourg
# Processing Record 12 of Set 4 | svobodnyy
# Processing Record 13 of Set 4 | avera
# Processing Record 14 of Set 4 | filadelfia
# Processing Record 15 of Set 4 | venice
# Processing Record 16 of Set 4 | samarai
# Processing Record 17 of Set 4 | marienburg
# Processing Record 18 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 19 of Set 4 | haines junction
# Processing Record 20 of Set 4 | kaniama
# Processing Record 21 of Set 4 | necochea
# Processing Record 22 of Set 4 | seidu
# Processing Record 23 of Set 4 | xining
# Processing Record 24 of Set 4 | kununurra
# Processing Record 25 of Set 4 | pueblo nuevo
# Processing Record 26 of Set 4 | souillac
# Processing Record 27 of Set 4 | enna
# Processing Record 28 of Set 4 | tuatapere
# Processing Record 29 of Set 4 | nacogdoches
# Processing Record 30 of Set 4 | marsh harbour
# Processing Record 31 of Set 4 | bucerias
# Processing Record 32 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 4 | aykhal
# Processing Record 34 of Set 4 | harboore
# Processing Record 35 of Set 4 | itarema
# Processing Record 36 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 37 of Set 4 | batemans bay
# Processing Record 38 of Set 4 | hofn
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | yibin
# Processing Record 41 of Set 4 | hecun
# Processing Record 42 of Set 4 | muzhi
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | waddan
# Processing Record 45 of Set 4 | ketou
# Processing Record 46 of Set 4 | mandapam
# Processing Record 47 of Set 4 | winnemucca
# Processing Record 48 of Set 4 | muros
# Processing Record 49 of Set 4 | bethel
# Processing Record 50 of Set 4 | namibe
# Processing Record 1 of Set 5 | sitka
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | praia
# Processing Record 4 of Set 5 | sharlyk
# Processing Record 5 of Set 5 | arzgir
# Processing Record 6 of Set 5 | marsa matruh
# Processing Record 7 of Set 5 | traverse city
# Processing Record 8 of Set 5 | dutse
# Processing Record 9 of Set 5 | laurel
# Processing Record 10 of Set 5 | lagoa
# Processing Record 11 of Set 5 | okoneshnikovo
# Processing Record 12 of Set 5 | biak
# Processing Record 13 of Set 5 | barsovo
# Processing Record 14 of Set 5 | touros
# Processing Record 15 of Set 5 | lluta
# Processing Record 16 of Set 5 | aklavik
# Processing Record 17 of Set 5 | namatanai
# Processing Record 18 of Set 5 | kutum
# Processing Record 19 of Set 5 | kahului
# Processing Record 20 of Set 5 | black diamond
# Processing Record 21 of Set 5 | ambulu
# Processing Record 22 of Set 5 | padrauna
# Processing Record 23 of Set 5 | nanpiao
# Processing Record 24 of Set 5 | prince rupert
# Processing Record 25 of Set 5 | ponta delgada
# Processing Record 26 of Set 5 | ambilobe
# Processing Record 27 of Set 5 | kieta
# Processing Record 28 of Set 5 | college
# Processing Record 29 of Set 5 | port blair
# Processing Record 30 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 5 | torbay
# Processing Record 32 of Set 5 | erzin
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | cardston
# Processing Record 35 of Set 5 | isla mujeres
# Processing Record 36 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 5 | gillette
# Processing Record 38 of Set 5 | clyde river
# Processing Record 39 of Set 5 | margate
# Processing Record 40 of Set 5 | prescott
# Processing Record 41 of Set 5 | tonj
# Processing Record 42 of Set 5 | lata
# Processing Record 43 of Set 5 | banda aceh
# Processing Record 44 of Set 5 | lebu
# Processing Record 45 of Set 5 | katangli
# Processing Record 46 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 47 of Set 5 | fougamou
# Processing Record 48 of Set 5 | lasa
# Processing Record 49 of Set 5 | pangnirtung
# Processing Record 50 of Set 5 | rundu
# Processing Record 1 of Set 6 | lima
# Processing Record 2 of Set 6 | koungou
# Processing Record 3 of Set 6 | michigan city
# Processing Record 4 of Set 6 | cam ranh
# Processing Record 5 of Set 6 | bilasipara
# Processing Record 6 of Set 6 | maputo
# Processing Record 7 of Set 6 | airai
# Processing Record 8 of Set 6 | calategas
# City not found. Skipping...
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | rafsanjan
# Processing Record 11 of Set 6 | caninde de sao francisco
# Processing Record 12 of Set 6 | henties bay
# Processing Record 13 of Set 6 | cherskiy
# Processing Record 14 of Set 6 | broome
# Processing Record 15 of Set 6 | chicama
# Processing Record 16 of Set 6 | saint-pierre
# Processing Record 17 of Set 6 | riberalta
# Processing Record 18 of Set 6 | kloulklubed
# Processing Record 19 of Set 6 | beloha
# Processing Record 20 of Set 6 | kasongo-lunda
# Processing Record 21 of Set 6 | uvat
# Processing Record 22 of Set 6 | lakhipur
# Processing Record 23 of Set 6 | viedma
# Processing Record 24 of Set 6 | egvekinot
# Processing Record 25 of Set 6 | kamarion
# Processing Record 26 of Set 6 | saint-joseph
# Processing Record 27 of Set 6 | taoudenni
# Processing Record 28 of Set 6 | adrar
# Processing Record 29 of Set 6 | saint-denis
# Processing Record 30 of Set 6 | santa cruz de tenerife
# Processing Record 31 of Set 6 | hun
# Processing Record 32 of Set 6 | sao filipe
# Processing Record 33 of Set 6 | harlingen
# Processing Record 34 of Set 6 | ojinaga
# Processing Record 35 of Set 6 | griffith
# Processing Record 36 of Set 6 | aitape
# Processing Record 37 of Set 6 | moussoro
# Processing Record 38 of Set 6 | krasnyy bogatyr
# Processing Record 39 of Set 6 | ancud
# Processing Record 40 of Set 6 | lakewood
# Processing Record 41 of Set 6 | along
# Processing Record 42 of Set 6 | torrijos
# Processing Record 43 of Set 6 | poso
# Processing Record 44 of Set 6 | orlik
# Processing Record 45 of Set 6 | syamzha
# Processing Record 46 of Set 6 | kostomuksha
# Processing Record 47 of Set 6 | flinders
# Processing Record 48 of Set 6 | fare
# Processing Record 49 of Set 6 | kant
# Processing Record 50 of Set 6 | port alfred
# Processing Record 1 of Set 7 | beaverlodge
# Processing Record 2 of Set 7 | erie
# Processing Record 3 of Set 7 | ahipara
# Processing Record 4 of Set 7 | yelizovo
# Processing Record 5 of Set 7 | waipawa
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | nanakuli
# Processing Record 8 of Set 7 | port hedland
# Processing Record 9 of Set 7 | kilindoni
# Processing Record 10 of Set 7 | hopelchen
# Processing Record 11 of Set 7 | bambous virieux
# Processing Record 12 of Set 7 | wonthaggi
# Processing Record 13 of Set 7 | ust-maya
# Processing Record 14 of Set 7 | baturaja
# Processing Record 15 of Set 7 | sioux lookout
# Processing Record 16 of Set 7 | hirna
# Processing Record 17 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 18 of Set 7 | chara
# Processing Record 19 of Set 7 | kamenka
# Processing Record 20 of Set 7 | youkounkoun
# Processing Record 21 of Set 7 | stepnoye
# Processing Record 22 of Set 7 | bijar
# Processing Record 23 of Set 7 | miramar
# Processing Record 24 of Set 7 | midyat
# Processing Record 25 of Set 7 | matara
# Processing Record 26 of Set 7 | saskylakh
# Processing Record 27 of Set 7 | sao joao de pirabas
# Processing Record 28 of Set 7 | brownwood
# Processing Record 29 of Set 7 | sorland
# Processing Record 30 of Set 7 | unye
# City not found. Skipping...
# Processing Record 31 of Set 7 | killybegs
# Processing Record 32 of Set 7 | tallahassee
# Processing Record 33 of Set 7 | diego de almagro
# Processing Record 34 of Set 7 | nikolskoye
# Processing Record 35 of Set 7 | magetan
# City not found. Skipping...
# Processing Record 36 of Set 7 | ejido
# Processing Record 37 of Set 7 | kaitangata
# Processing Record 38 of Set 7 | bykovo
# Processing Record 39 of Set 7 | parfenyevo
# Processing Record 40 of Set 7 | carnot
# Processing Record 41 of Set 7 | zlobin
# Processing Record 42 of Set 7 | bastrop
# Processing Record 43 of Set 7 | hare bay
# Processing Record 44 of Set 7 | anito
# Processing Record 45 of Set 7 | grand-santi
# Processing Record 46 of Set 7 | hai duong
# Processing Record 47 of Set 7 | isla vista
# Processing Record 48 of Set 7 | rudnya
# Processing Record 49 of Set 7 | mayo
# Processing Record 50 of Set 7 | salihorsk
# Processing Record 1 of Set 8 | pinalejo
# Processing Record 2 of Set 8 | dubbo
# Processing Record 3 of Set 8 | tabuk
# Processing Record 4 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 8 | havre-saint-pierre
# Processing Record 6 of Set 8 | igrim
# Processing Record 7 of Set 8 | rio gallegos
# Processing Record 8 of Set 8 | chabahar
# Processing Record 9 of Set 8 | bianzhuang
# Processing Record 10 of Set 8 | eureka
# Processing Record 11 of Set 8 | jatai
# Processing Record 12 of Set 8 | srandakan
# Processing Record 13 of Set 8 | roald
# Processing Record 14 of Set 8 | hendersonville
# Processing Record 15 of Set 8 | severomuysk
# Processing Record 16 of Set 8 | mulanje
# Processing Record 17 of Set 8 | rassvet
# Processing Record 18 of Set 8 | baruun-urt
# Processing Record 19 of Set 8 | kavieng
# Processing Record 20 of Set 8 | sechura
# Processing Record 21 of Set 8 | luau
# Processing Record 22 of Set 8 | ghanzi
# Processing Record 23 of Set 8 | wagar
# Processing Record 24 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | riyadh
# Processing Record 27 of Set 8 | ust-kachka
# Processing Record 28 of Set 8 | lazaro cardenas
# Processing Record 29 of Set 8 | kruisfontein
# Processing Record 30 of Set 8 | tanete
# Processing Record 31 of Set 8 | vytegra
# Processing Record 32 of Set 8 | banes
# Processing Record 33 of Set 8 | los llanos de aridane
# Processing Record 34 of Set 8 | klaksvik
# Processing Record 35 of Set 8 | mar del plata
# Processing Record 36 of Set 8 | keita
# Processing Record 37 of Set 8 | nome
# Processing Record 38 of Set 8 | zuenoula
# Processing Record 39 of Set 8 | craig
# Processing Record 40 of Set 8 | armidale
# Processing Record 41 of Set 8 | nouadhibou
# Processing Record 42 of Set 8 | port arthur
# Processing Record 43 of Set 8 | seoul
# Processing Record 44 of Set 8 | port lincoln
# Processing Record 45 of Set 8 | upata
# Processing Record 46 of Set 8 | bonavista
# Processing Record 47 of Set 8 | palmer
# Processing Record 48 of Set 8 | jumla
# Processing Record 49 of Set 8 | cocal
# Processing Record 50 of Set 8 | binabalian
# Processing Record 1 of Set 9 | yangjiang
# Processing Record 2 of Set 9 | raudeberg
# Processing Record 3 of Set 9 | laguna
# Processing Record 4 of Set 9 | gat
# Processing Record 5 of Set 9 | bagacay
# Processing Record 6 of Set 9 | soimi
# Processing Record 7 of Set 9 | itaituba
# Processing Record 8 of Set 9 | umm kaddadah
# Processing Record 9 of Set 9 | thompson
# Processing Record 10 of Set 9 | nakhon thai
# Processing Record 11 of Set 9 | sigulda
# Processing Record 12 of Set 9 | cockburn town
# Processing Record 13 of Set 9 | atbasar
# Processing Record 14 of Set 9 | nishihara
# Processing Record 15 of Set 9 | shubarshi
# Processing Record 16 of Set 9 | upernavik
# Processing Record 17 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 18 of Set 9 | shimoda
# Processing Record 19 of Set 9 | tilichiki
# Processing Record 20 of Set 9 | kuching
# Processing Record 21 of Set 9 | salinopolis
# Processing Record 22 of Set 9 | uchiza
# Processing Record 23 of Set 9 | atar
# Processing Record 24 of Set 9 | deputatskiy
# Processing Record 25 of Set 9 | imbituba
# Processing Record 26 of Set 9 | miri
# Processing Record 27 of Set 9 | kerouane
# Processing Record 28 of Set 9 | kocevje
# Processing Record 29 of Set 9 | sao raimundo das mangabeiras
# Processing Record 30 of Set 9 | sorong
# Processing Record 31 of Set 9 | wukari
# Processing Record 32 of Set 9 | usinsk
# Processing Record 33 of Set 9 | soure
# Processing Record 34 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 9 | cabo san lucas
# Processing Record 36 of Set 9 | baisha
# Processing Record 37 of Set 9 | camocim
# Processing Record 38 of Set 9 | uige
# Processing Record 39 of Set 9 | coihaique
# Processing Record 40 of Set 9 | harrisonburg
# Processing Record 41 of Set 9 | san andres
# Processing Record 42 of Set 9 | lompoc
# Processing Record 43 of Set 9 | mantua
# Processing Record 44 of Set 9 | yar-sale
# Processing Record 45 of Set 9 | solnechnyy
# Processing Record 46 of Set 9 | padampur
# Processing Record 47 of Set 9 | bayangol
# Processing Record 48 of Set 9 | koshki
# Processing Record 49 of Set 9 | kembolcha
# Processing Record 50 of Set 9 | la rioja
# Processing Record 1 of Set 10 | arrecife
# Processing Record 2 of Set 10 | russell
# Processing Record 3 of Set 10 | macomb
# Processing Record 4 of Set 10 | zaysan
# Processing Record 5 of Set 10 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 10 | chapais
# Processing Record 7 of Set 10 | milkovo
# Processing Record 8 of Set 10 | tarko-sale
# Processing Record 9 of Set 10 | arnes
# Processing Record 10 of Set 10 | pundaguitan
# Processing Record 11 of Set 10 | luanda
# Processing Record 12 of Set 10 | kedougou
# Processing Record 13 of Set 10 | santa fe
# Processing Record 14 of Set 10 | isangel
# Processing Record 15 of Set 10 | khorinsk
# Processing Record 16 of Set 10 | talnakh
# Processing Record 17 of Set 10 | padang
# Processing Record 18 of Set 10 | crab hill
# City not found. Skipping...
# Processing Record 19 of Set 10 | sept-iles
# Processing Record 20 of Set 10 | mahuva
# Processing Record 21 of Set 10 | tottori
# Processing Record 22 of Set 10 | hamilton
# Processing Record 23 of Set 10 | mangan
# Processing Record 24 of Set 10 | lieksa
# Processing Record 25 of Set 10 | victoria
# Processing Record 26 of Set 10 | lucapa
# Processing Record 27 of Set 10 | bereda
# Processing Record 28 of Set 10 | rio grande
# Processing Record 29 of Set 10 | iglesias
# Processing Record 30 of Set 10 | zamora
# Processing Record 31 of Set 10 | srednekolymsk
# Processing Record 32 of Set 10 | codrington
# Processing Record 33 of Set 10 | kavaratti
# Processing Record 34 of Set 10 | walvis bay
# Processing Record 35 of Set 10 | levelland
# Processing Record 36 of Set 10 | filingue
# Processing Record 37 of Set 10 | la ronge
# Processing Record 38 of Set 10 | kathu
# Processing Record 39 of Set 10 | tsukumi
# Processing Record 40 of Set 10 | luorong
# Processing Record 41 of Set 10 | mukhen
# Processing Record 42 of Set 10 | sahuaripa
# Processing Record 43 of Set 10 | camana
# Processing Record 44 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 45 of Set 10 | moranbah
# Processing Record 46 of Set 10 | paita
# Processing Record 47 of Set 10 | nautanwa
# Processing Record 48 of Set 10 | fort nelson
# Processing Record 49 of Set 10 | sobolevo
# Processing Record 50 of Set 10 | amapa
# Processing Record 1 of Set 11 | nago
# Processing Record 2 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 3 of Set 11 | broken hill
# Processing Record 4 of Set 11 | katherine
# Processing Record 5 of Set 11 | maningrida
# Processing Record 6 of Set 11 | cururupu
# Processing Record 7 of Set 11 | qingdao
# Processing Record 8 of Set 11 | dvinskoy
# Processing Record 9 of Set 11 | ranong
# Processing Record 10 of Set 11 | mirnyy
# Processing Record 11 of Set 11 | te anau
# Processing Record 12 of Set 11 | estevan
# Processing Record 13 of Set 11 | dryden
# Processing Record 14 of Set 11 | arlit
# Processing Record 15 of Set 11 | nadym
# Processing Record 16 of Set 11 | ouro preto do oeste
# Processing Record 17 of Set 11 | assiniboia
# Processing Record 18 of Set 11 | ahero
# Processing Record 19 of Set 11 | borba
# Processing Record 20 of Set 11 | vakhrushev
# Processing Record 21 of Set 11 | luderitz
# Processing Record 22 of Set 11 | san jeronimo
# Processing Record 23 of Set 11 | vanimo
# Processing Record 24 of Set 11 | vagur
# Processing Record 25 of Set 11 | sakakah
# Processing Record 26 of Set 11 | chhatak
# Processing Record 27 of Set 11 | nador
# Processing Record 28 of Set 11 | rosetta
# Processing Record 29 of Set 11 | porto nacional
# Processing Record 30 of Set 11 | manado
# Processing Record 31 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 32 of Set 11 | saint anthony
# Processing Record 33 of Set 11 | salalah
# Processing Record 34 of Set 11 | sungai pelek
# Processing Record 35 of Set 11 | brae
# Processing Record 36 of Set 11 | dir
# Processing Record 37 of Set 11 | moose factory
# Processing Record 38 of Set 11 | barreirinhas
# Processing Record 39 of Set 11 | lugovoy
# Processing Record 40 of Set 11 | lewistown
# Processing Record 41 of Set 11 | stokmarknes
# Processing Record 42 of Set 11 | kumluca
# Processing Record 43 of Set 11 | capao bonito
# Processing Record 44 of Set 11 | vertou
# Processing Record 45 of Set 11 | yerofey pavlovich
# Processing Record 46 of Set 11 | gorontalo
# Processing Record 47 of Set 11 | makueni
# Processing Record 48 of Set 11 | indian head
# Processing Record 49 of Set 11 | mayumba
# Processing Record 50 of Set 11 | meulaboh
# Processing Record 1 of Set 12 | iqaluit
# Processing Record 2 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 12 | grand gaube
# Processing Record 4 of Set 12 | mogadishu
# Processing Record 5 of Set 12 | toccoa
# Processing Record 6 of Set 12 | deniliquin
# Processing Record 7 of Set 12 | kenai
# Processing Record 8 of Set 12 | rakaia
# Processing Record 9 of Set 12 | razdolnoye
# Processing Record 10 of Set 12 | kashi
# Processing Record 11 of Set 12 | ergani
# Processing Record 12 of Set 12 | shahabad
# Processing Record 13 of Set 12 | krasnyy profintern
# Processing Record 14 of Set 12 | halifax
# Processing Record 15 of Set 12 | leh
# Processing Record 16 of Set 12 | chingirlau
# Processing Record 17 of Set 12 | nemuro
# Processing Record 18 of Set 12 | nsoko
# Processing Record 19 of Set 12 | porto novo
# Processing Record 20 of Set 12 | waverley
# Processing Record 21 of Set 12 | homer
# Processing Record 22 of Set 12 | kapellen
# Processing Record 23 of Set 12 | nikki
# Processing Record 24 of Set 12 | makungu
# Processing Record 25 of Set 12 | gisors
# Processing Record 26 of Set 12 | outjo
# Processing Record 27 of Set 12 | vestbygda
# City not found. Skipping...
# Processing Record 28 of Set 12 | zilair
# Processing Record 29 of Set 12 | pokhara
# Processing Record 30 of Set 12 | evensk
# Processing Record 31 of Set 12 | svetlogorsk
# Processing Record 32 of Set 12 | rodos
# Processing Record 33 of Set 12 | pandan
# Processing Record 34 of Set 12 | princeton
# Processing Record 35 of Set 12 | belen
# Processing Record 36 of Set 12 | yerbogachen
# Processing Record 37 of Set 12 | cabanas
# Processing Record 38 of Set 12 | taywarah
# Processing Record 39 of Set 12 | taber
# Processing Record 40 of Set 12 | makhachkala
# Processing Record 41 of Set 12 | portland
# Processing Record 42 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 12 | ushtobe
# Processing Record 44 of Set 12 | sturgeon falls
# Processing Record 45 of Set 12 | potosi
# Processing Record 46 of Set 12 | carballo
# Processing Record 47 of Set 12 | gouyave
# Processing Record 48 of Set 12 | north platte
# Processing Record 49 of Set 12 | pozo colorado
# Processing Record 50 of Set 12 | zhangye
# Processing Record 1 of Set 13 | changping
# Processing Record 2 of Set 13 | kailua
# Processing Record 3 of Set 13 | nantucket
# Processing Record 4 of Set 13 | wellington
# Processing Record 5 of Set 13 | mehamn
# Processing Record 6 of Set 13 | hovd
# Processing Record 7 of Set 13 | araouane
# Processing Record 8 of Set 13 | terme
# Processing Record 9 of Set 13 | huarmey
# Processing Record 10 of Set 13 | lao cai
# Processing Record 11 of Set 13 | iracoubo
# Processing Record 12 of Set 13 | byron bay
# Processing Record 13 of Set 13 | fort-shevchenko
# Processing Record 14 of Set 13 | nova borova
# Processing Record 15 of Set 13 | aksarka
# Processing Record 16 of Set 13 | kulunda
# Processing Record 17 of Set 13 | hluti
# Processing Record 18 of Set 13 | honiara
# Processing Record 19 of Set 13 | fernley
# Processing Record 20 of Set 13 | barcelos
# Processing Record 21 of Set 13 | vallenar
# Processing Record 22 of Set 13 | chimbarongo
# Processing Record 23 of Set 13 | la tuque
# Processing Record 24 of Set 13 | dongsheng
# Processing Record 25 of Set 13 | karlskrona
# Processing Record 26 of Set 13 | tranas
# Processing Record 27 of Set 13 | mitchell
# Processing Record 28 of Set 13 | saint-francois
# Processing Record 29 of Set 13 | kyzyl-suu
# Processing Record 30 of Set 13 | batticaloa
# Processing Record 31 of Set 13 | inuvik
# Processing Record 32 of Set 13 | sakaiminato
# Processing Record 33 of Set 13 | zychlin
# Processing Record 34 of Set 13 | mirabad
# Processing Record 35 of Set 13 | noumea
# Processing Record 36 of Set 13 | susanville
# Processing Record 37 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 13 | minab
# Processing Record 39 of Set 13 | coahuayana
# Processing Record 40 of Set 13 | springdale
# Processing Record 41 of Set 13 | naze
# Processing Record 42 of Set 13 | makakilo city
# Processing Record 43 of Set 13 | podujevo
# Processing Record 44 of Set 13 | abu kamal
# Processing Record 45 of Set 13 | weligama
# Processing Record 46 of Set 13 | teixoso
# Processing Record 47 of Set 13 | vostok
# Processing Record 48 of Set 13 | toamasina
# Processing Record 49 of Set 13 | saint-leu
# Processing Record 50 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 14 | launceston
# Processing Record 2 of Set 14 | nouakchott
# Processing Record 3 of Set 14 | kurchum
# Processing Record 4 of Set 14 | ostrovnoy
# Processing Record 5 of Set 14 | bezhetsk
# Processing Record 6 of Set 14 | shirokiy
# Processing Record 7 of Set 14 | mackay
# Processing Record 8 of Set 14 | calabar
# Processing Record 9 of Set 14 | tsabong
# Processing Record 10 of Set 14 | polovinnoye
# Processing Record 11 of Set 14 | tucurui
# Processing Record 12 of Set 14 | iquique
# Processing Record 13 of Set 14 | spencer
# Processing Record 14 of Set 14 | vaijapur
# Processing Record 15 of Set 14 | inhambane
# Processing Record 16 of Set 14 | sijunjung
# Processing Record 17 of Set 14 | lufilufi
# Processing Record 18 of Set 14 | tiznit
# Processing Record 19 of Set 14 | taganak
# Processing Record 20 of Set 14 | tha mai
# Processing Record 21 of Set 14 | ascension
# Processing Record 22 of Set 14 | grindavik
# Processing Record 23 of Set 14 | celestun
# Processing Record 24 of Set 14 | ulkan
# Processing Record 25 of Set 14 | dabat
# Processing Record 26 of Set 14 | binzhou
# Processing Record 27 of Set 14 | artvin
# Processing Record 28 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 29 of Set 14 | voskresenskoye
# Processing Record 30 of Set 14 | ialibu
# Processing Record 31 of Set 14 | gazanjyk
# Processing Record 32 of Set 14 | santa cruz del sur
# Processing Record 33 of Set 14 | kapoeta
# Processing Record 34 of Set 14 | cedar city
# Processing Record 35 of Set 14 | hailar
# Processing Record 36 of Set 14 | soyalo
# Processing Record 37 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 14 | janakpur road
# City not found. Skipping...
# Processing Record 39 of Set 14 | montivilliers
# Processing Record 40 of Set 14 | popondetta
# Processing Record 41 of Set 14 | hobyo
# Processing Record 42 of Set 14 | malia
# Processing Record 43 of Set 14 | yarkovo
# Processing Record 44 of Set 14 | gurskoye
# City not found. Skipping...
# Processing Record 45 of Set 14 | sajanan
# Processing Record 46 of Set 14 | raymond terrace
# Processing Record 47 of Set 14 | amethi
# Processing Record 48 of Set 14 | maarianhamina
# Processing Record 49 of Set 14 | wangaratta
# Processing Record 50 of Set 14 | sendai
# Processing Record 1 of Set 15 | dunedin
# Processing Record 2 of Set 15 | taga dzong
# City not found. Skipping...
# Processing Record 3 of Set 15 | springbok
# Processing Record 4 of Set 15 | yairipok
# Processing Record 5 of Set 15 | bethanien
# Processing Record 6 of Set 15 | hervey bay
# Processing Record 7 of Set 15 | kyra
# Processing Record 8 of Set 15 | abu jubayhah
# City not found. Skipping...
# Processing Record 9 of Set 15 | tawzar
# City not found. Skipping...
# Processing Record 10 of Set 15 | sidi bu zayd
# City not found. Skipping...
# Processing Record 11 of Set 15 | vung tau
# Processing Record 12 of Set 15 | dudinka
# Processing Record 13 of Set 15 | kyaukse
# Processing Record 14 of Set 15 | shieli
# Processing Record 15 of Set 15 | toftir
# City not found. Skipping...
# Processing Record 16 of Set 15 | gazli
# Processing Record 17 of Set 15 | ajdabiya
# Processing Record 18 of Set 15 | gazni
# City not found. Skipping...
# Processing Record 19 of Set 15 | korba
# Processing Record 20 of Set 15 | jodhpur
# Processing Record 21 of Set 15 | yumen
# Processing Record 22 of Set 15 | porto torres
# Processing Record 23 of Set 15 | ndola
# Processing Record 24 of Set 15 | bolshaya irba
# City not found. Skipping...
# Processing Record 25 of Set 15 | staszow
# Processing Record 26 of Set 15 | san quintin
# Processing Record 27 of Set 15 | morondava
# Processing Record 28 of Set 15 | ishigaki
# Processing Record 29 of Set 15 | asau
# Processing Record 30 of Set 15 | arfara
# Processing Record 31 of Set 15 | kaoma
# Processing Record 32 of Set 15 | garhi yasin
# Processing Record 33 of Set 15 | paamiut
# Processing Record 34 of Set 15 | crixas
# Processing Record 35 of Set 15 | deer lake
# Processing Record 36 of Set 15 | balkanabat
# Processing Record 37 of Set 15 | ganzhou
# Processing Record 38 of Set 15 | westport
# Processing Record 39 of Set 15 | vangaindrano
# Processing Record 40 of Set 15 | kirakira
# Processing Record 41 of Set 15 | takefu
# Processing Record 42 of Set 15 | pudozh
# Processing Record 43 of Set 15 | bolshaya murta
# City not found. Skipping...
# Processing Record 44 of Set 15 | cabatuan
# Processing Record 45 of Set 15 | mehran
# Processing Record 46 of Set 15 | omboue
# Processing Record 47 of Set 15 | navoi
# Processing Record 48 of Set 15 | vaitape
# Processing Record 49 of Set 15 | oyama
# Processing Record 50 of Set 15 | alihe
# Processing Record 1 of Set 16 | zhigansk
# Processing Record 2 of Set 16 | muborak
# Processing Record 3 of Set 16 | rawlins
# Processing Record 4 of Set 16 | skibbereen
# Processing Record 5 of Set 16 | bahia blanca
# Processing Record 6 of Set 16 | suntar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Langsa',
#   'Lat': 4.4683,
#   'Lng': 97.9683,
#   'Max Temp': 74.07,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 92,
#   'Wind Speed': 2.77,
#   'Country': 'ID'},
#  {'City': 'Hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 79.2,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 95,
#   'Wind Speed': 17.69,
#   'Country': 'LK'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.6403,
#   'Lng': -41.0511,
#   'Max Temp': 78.89,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 13.91,
#   'Country': 'BR'},
#  {'City': 'San Patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 98.17,
#   'Current Description': 'clear sky',
#   'Humidity': 42,
#   'Cloudiness': 4,
#   'Wind Speed': 17.31,
#   'Country': 'US'},
#  {'City': 'Wanaka',
#   'Lat': -44.7,
#   'Lng': 169.15,
#   'Max Temp': 22.17,
#   'Current Description': 'few clouds',
#   'Humidity': 92,
#   'Cloudiness': 23,
#   'Wind Speed': 2.75,
#   'Country': 'NZ'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 50.25,
#   'Current Description': 'overcast clouds',
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'AU'},
#  {'City': 'Labuhan',
#   'Lat': -6.8844,
#   'Lng': 112.2051,
#   'Max Temp': 75.29,
#   'Current Description': 'broken clouds',
#   'Humidity': 84,
#   'Cloudiness': 55,
#   'Wind Speed': 7.67,
#   'Country': 'ID'},
#  {'City': 'Mujiayingzi',
#   'Lat': 42.1167,
#   'Lng': 118.7833,
#   'Max Temp': 66.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Country': 'CN'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 66.67,
#   'Current Description': 'light rain',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'BR'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 33.46,
#   'Current Description': 'sleet',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 23.02,
#   'Country': 'AR'},
#  {'City': 'Pithoragarh',
#   'Lat': 29.5833,
#   'Lng': 80.2167,
#   'Max Temp': 65.79,
#   'Current Description': 'light rain',
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.21,
#   'Country': 'IN'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 71.76,
#   'Current Description': 'few clouds',
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'TO'},
#  {'City': 'Vila Velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 78.75,
#   'Current Description': 'few clouds',
#   'Humidity': 77,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'BR'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 63.28,
#   'Current Description': 'scattered clouds',
#   'Humidity': 75,
#   'Cloudiness': 42,
#   'Wind Speed': 3.89,
#   'Country': 'UY'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 33.48,
#   'Current Description': 'few clouds',
#   'Humidity': 98,
#   'Cloudiness': 15,
#   'Wind Speed': 2.95,
#   'Country': 'NZ'},
#  {'City': 'Nanortalik',
#   'Lat': 60.1432,
#   'Lng': -45.2371,
#   'Max Temp': 49.01,
#   'Current Description': 'few clouds',
#   'Humidity': 79,
#   'Cloudiness': 17,
#   'Wind Speed': 4.05,
#   'Country': 'GL'},
#  {'City': 'Nevesinje',
#   'Lat': 43.2586,
#   'Lng': 18.1133,
#   'Max Temp': 70.92,
#   'Current Description': 'clear sky',
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'BA'},
#  {'City': 'Gannan',
#   'Lat': 47.9147,
#   'Lng': 123.5031,
#   'Max Temp': 66.22,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 70,
#   'Wind Speed': 3.42,
#   'Country': 'CN'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 41.7,
#   'Current Description': 'overcast clouds',
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 13.42,
#   'Country': 'RU'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 80.92,
#   'Current Description': 'scattered clouds',
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 66.07,
#   'Current Description': 'scattered clouds',
#   'Humidity': 72,
#   'Cloudiness': 31,
#   'Wind Speed': 9.55,
#   'Country': 'PE'},
#  {'City': 'Ekibastuz',
#   'Lat': 51.6667,
#   'Lng': 75.3667,
#   'Max Temp': 67.32,
#   'Current Description': 'scattered clouds',
#   'Humidity': 56,
#   'Cloudiness': 33,
#   'Wind Speed': 7.61,
#   'Country': 'KZ'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 65.01,
#   'Current Description': 'overcast clouds',
#   'Humidity': 49,
#   'Cloudiness': 90,
#   'Wind Speed': 9.53,
#   'Country': 'CA'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 82.27,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Bathsheba',
#   'Lat': 13.2167,
#   'Lng': -59.5167,
#   'Max Temp': 86.61,
#   'Current Description': 'few clouds',
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'BB'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 93.16,
#   'Current Description': 'clear sky',
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 41.02,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Country': 'CL'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 41.41,
#   'Current Description': 'light rain',
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 12.77,
#   'Country': 'RU'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 56.71,
#   'Current Description': 'clear sky',
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Oum Hadjer',
#   'Lat': 13.2954,
#   'Lng': 19.6966,
#   'Max Temp': 76.23,
#   'Current Description': 'light rain',
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 18.21,
#   'Country': 'TD'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 63.07,
#   'Current Description': 'clear sky',
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 12.73,
#   'Country': 'AU'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 39.22,
#   'Current Description': 'mist',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 49.91,
#   'Current Description': 'overcast clouds',
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'AU'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 72.37,
#   'Current Description': 'overcast clouds',
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 9.62,
#   'Country': 'PF'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 72.01,
#   'Current Description': 'overcast clouds',
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 1.61,
#   'Country': 'PT'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 54.81,
#   'Current Description': 'light rain',
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Country': 'ZA'},
#  {'City': 'Marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 69.15,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'PH'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 33.8,
#   'Current Description': 'few clouds',
#   'Humidity': 84,
#   'Cloudiness': 11,
#   'Wind Speed': 6.87,
#   'Country': 'NZ'},
#  {'City': 'Pangody',
#   'Lat': 65.85,
#   'Lng': 74.4859,
#   'Max Temp': 46.15,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 4.36,
#   'Country': 'RU'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 69.22,
#   'Current Description': 'scattered clouds',
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'PT'},
#  {'City': 'Majene',
#   'Lat': -3.5403,
#   'Lng': 118.9707,
#   'Max Temp': 77.47,
#   'Current Description': 'broken clouds',
#   'Humidity': 89,
#   'Cloudiness': 71,
#   'Wind Speed': 11.16,
#   'Country': 'ID'},
#  {'City': 'Faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 77.9,
#   'Current Description': 'light rain',
#   'Humidity': 74,
#   'Cloudiness': 16,
#   'Wind Speed': 10,
#   'Country': 'PF'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 68.56,
#   'Current Description': 'few clouds',
#   'Humidity': 42,
#   'Cloudiness': 23,
#   'Wind Speed': 4.47,
#   'Country': 'ZA'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 32.09,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'RU'},
#  {'City': 'San Jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 88.92,
#   'Current Description': 'few clouds',
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 46.06,
#   'Current Description': 'scattered clouds',
#   'Humidity': 68,
#   'Cloudiness': 26,
#   'Wind Speed': 9.6,
#   'Country': 'RU'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 58.82,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 14,
#   'Wind Speed': 15.73,
#   'Country': 'AU'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 77.05,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'CK'},
#  {'City': 'Lafia',
#   'Lat': 8.4833,
#   'Lng': 8.5167,
#   'Max Temp': 74.73,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 3.53,
#   'Country': 'NG'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 78.73,
#   'Current Description': 'few clouds',
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MY'},
#  {'City': 'Thayetmyo',
#   'Lat': 19.3167,
#   'Lng': 95.1833,
#   'Max Temp': 75.34,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.03,
#   'Country': 'MM'},
#  {'City': 'Kushiro',
#   'Lat': 42.975,
#   'Lng': 144.3747,
#   'Max Temp': 59.9,
#   'Current Description': 'light rain',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 14.18,
#   'Country': 'JP'},
#  {'City': 'Pacific Grove',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 79.39,
#   'Current Description': 'scattered clouds',
#   'Humidity': 86,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'US'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 51.46,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 51,
#   'Wind Speed': 4.85,
#   'Country': 'IS'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 75.7,
#   'Current Description': 'clear sky',
#   'Humidity': 73,
#   'Cloudiness': 3,
#   'Wind Speed': 6.53,
#   'Country': 'PT'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 44.29,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 14.23,
#   'Country': 'RU'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 77.22,
#   'Current Description': 'clear sky',
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 14.74,
#   'Country': 'PF'},
#  {'City': 'Whitley Bay',
#   'Lat': 55.0397,
#   'Lng': -1.4471,
#   'Max Temp': 60.08,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'GB'},
#  {'City': 'Kitimat',
#   'Lat': 54.0524,
#   'Lng': -128.6534,
#   'Max Temp': 67.91,
#   'Current Description': 'broken clouds',
#   'Humidity': 55,
#   'Cloudiness': 78,
#   'Wind Speed': 3,
#   'Country': 'CA'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 81.88,
#   'Current Description': 'overcast clouds',
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.56,
#   'Country': 'MV'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 47.41,
#   'Current Description': 'broken clouds',
#   'Humidity': 77,
#   'Cloudiness': 64,
#   'Wind Speed': 5.68,
#   'Country': 'RU'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 55.15,
#   'Current Description': 'overcast clouds',
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 8.86,
#   'Country': 'ZA'},
#  {'City': 'Leshukonskoye',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 65.08,
#   'Current Description': 'few clouds',
#   'Humidity': 67,
#   'Cloudiness': 22,
#   'Wind Speed': 6.4,
#   'Country': 'RU'},
#  {'City': 'Fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 63.93,
#   'Current Description': 'few clouds',
#   'Humidity': 76,
#   'Cloudiness': 11,
#   'Wind Speed': 1.01,
#   'Country': 'US'},
#  {'City': 'Batagay',
#   'Lat': 67.6333,
#   'Lng': 134.6333,
#   'Max Temp': 63.82,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'RU'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 66.72,
#   'Current Description': 'broken clouds',
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 3.56,
#   'Country': 'SA'},
#  {'City': 'Acapulco',
#   'Lat': 16.8634,
#   'Lng': -99.8901,
#   'Max Temp': 87.62,
#   'Current Description': 'overcast clouds',
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'MX'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 56.21,
#   'Current Description': 'clear sky',
#   'Humidity': 39,
#   'Cloudiness': 6,
#   'Wind Speed': 9.37,
#   'Country': 'AU'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 58.26,
#   'Current Description': 'light rain',
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'ZA'},
#  {'City': 'Gwadar',
#   'Lat': 25.1216,
#   'Lng': 62.3254,
#   'Max Temp': 83.05,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 70,
#   'Wind Speed': 10.78,
#   'Country': 'PK'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 85.08,
#   'Current Description': 'clear sky',
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'GF'},
#  {'City': 'Tura',
#   'Lat': 25.5198,
#   'Lng': 90.2201,
#   'Max Temp': 75.74,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Country': 'IN'},
#  {'City': 'Odweyne',
#   'Lat': 9.4092,
#   'Lng': 45.064,
#   'Max Temp': 74.05,
#   'Current Description': 'clear sky',
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 19.24,
#   'Country': 'SO'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 42.66,
#   'Current Description': 'clear sky',
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'AR'},
#  {'City': 'Shitkino',
#   'Lat': 56.3703,
#   'Lng': 98.3543,
#   'Max Temp': 57.31,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 2.48,
#   'Country': 'RU'},
#  {'City': 'Richards Bay',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 67.44,
#   'Current Description': 'clear sky',
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 11.23,
#   'Country': 'ZA'},
#  {'City': 'Shunyi',
#   'Lat': 40.125,
#   'Lng': 116.6453,
#   'Max Temp': 71.55,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.95,
#   'Country': 'CN'},
#  {'City': 'Santa Catarina De Tepehuanes',
#   'Lat': 25.35,
#   'Lng': -105.7333,
#   'Max Temp': 82.94,
#   'Current Description': 'overcast clouds',
#   'Humidity': 35,
#   'Cloudiness': 86,
#   'Wind Speed': 10,
#   'Country': 'MX'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 43.21,
#   'Current Description': 'light rain',
#   'Humidity': 77,
#   'Cloudiness': 99,
#   'Wind Speed': 8.9,
#   'Country': 'GL'},
#  {'City': 'Klyuchi',
#   'Lat': 52.2667,
#   'Lng': 79.1667,
#   'Max Temp': 64.24,
#   'Current Description': 'clear sky',
#   'Humidity': 66,
#   'Cloudiness': 3,
#   'Wind Speed': 7.76,
#   'Country': 'RU'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 53.58,
#   'Current Description': 'scattered clouds',
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Country': 'NO'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 75.78,
#   'Current Description': 'scattered clouds',
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 19.55,
#   'Country': 'MX'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 49.84,
#   'Current Description': 'broken clouds',
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'SJ'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 75.6,
#   'Current Description': 'clear sky',
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 18.43,
#   'Country': 'JP'},
#  {'City': 'Hudson Bay',
#   'Lat': 52.85,
#   'Lng': -102.3842,
#   'Max Temp': 71.33,
#   'Current Description': 'overcast clouds',
#   'Humidity': 48,
#   'Cloudiness': 99,
#   'Wind Speed': 7.99,
#   'Country': 'CA'},
#  {'City': 'Vuktyl',
#   'Lat': 63.8567,
#   'Lng': 57.3094,
#   'Max Temp': 46.4,
#   'Current Description': 'few clouds',
#   'Humidity': 79,
#   'Cloudiness': 11,
#   'Wind Speed': 4.56,
#   'Country': 'RU'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.98,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 13,
#   'Wind Speed': 8.97,
#   'Country': 'KI'},
#  {'City': 'Olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 54,
#   'Current Description': 'few clouds',
#   'Humidity': 77,
#   'Cloudiness': 13,
#   'Wind Speed': 3.91,
#   'Country': 'IS'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.06,
#   'Current Description': 'clear sky',
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Country': 'BR'},
#  {'City': 'Takoradi',
#   'Lat': 4.8845,
#   'Lng': -1.7554,
#   'Max Temp': 75.74,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 10.2,
#   'Country': 'GH'},
#  {'City': 'Qaqortoq',
#   'Lat': 60.7167,
#   'Lng': -46.0333,
#   'Max Temp': 51.3,
#   'Current Description': 'scattered clouds',
#   'Humidity': 72,
#   'Cloudiness': 26,
#   'Wind Speed': 4.34,
#   'Country': 'GL'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 60.31,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'ZA'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 78.66,
#   'Current Description': 'clear sky',
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 18.88,
#   'Country': 'JP'},
#  {'City': 'Deloraine',
#   'Lat': -41.5333,
#   'Lng': 146.6667,
#   'Max Temp': 50.36,
#   'Current Description': 'moderate rain',
#   'Humidity': 15,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'AU'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 85.01,
#   'Current Description': 'few clouds',
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'US'},
#  {'City': 'Lensk',
#   'Lat': 60.7253,
#   'Lng': 114.9278,
#   'Max Temp': 61.92,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Country': 'RU'},
#  {'City': 'Fairbanks',
#   'Lat': 64.8378,
#   'Lng': -147.7164,
#   'Max Temp': 55.36,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 59.95,
#   'Current Description': 'few clouds',
#   'Humidity': 77,
#   'Cloudiness': 11,
#   'Wind Speed': 12.46,
#   'Country': 'RU'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 41.16,
#   'Current Description': 'scattered clouds',
#   'Humidity': 72,
#   'Cloudiness': 38,
#   'Wind Speed': 7.81,
#   'Country': 'GL'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 53.02,
#   'Current Description': 'overcast clouds',
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 12.84,
#   'Country': 'RU'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 72.7,
#   'Current Description': 'broken clouds',
#   'Humidity': 49,
#   'Cloudiness': 78,
#   'Wind Speed': 5.37,
#   'Country': 'BR'},
#  {'City': 'Half Moon Bay',
#   'Lat': 37.4636,
#   'Lng': -122.4286,
#   'Max Temp': 83.88,
#   'Current Description': 'mist',
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Country': 'US'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 53.62,
#   'Current Description': 'light rain',
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'GL'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 56.14,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.83,
#   'Country': 'ZA'},
#  {'City': 'Poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 76.93,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 93,
#   'Wind Speed': 17.02,
#   'Country': 'NC'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 76.59,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 94,
#   'Wind Speed': 4.99,
#   'Country': 'PH'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 77.4,
#   'Current Description': 'scattered clouds',
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'PT'},
#  {'City': 'Zarechnyy',
#   'Lat': 53.2036,
#   'Lng': 45.1923,
#   'Max Temp': 58.8,
#   'Current Description': 'light rain',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'RU'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 51.08,
#   'Current Description': 'light rain',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 10.18,
#   'Country': 'AU'},
#  {'City': 'Khasan',
#   'Lat': 42.4308,
#   'Lng': 130.6434,
#   'Max Temp': 65.41,
#   'Current Description': 'overcast clouds',
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'RU'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 80.56,
#   'Current Description': 'few clouds',
#   'Humidity': 84,
#   'Cloudiness': 17,
#   'Wind Speed': 8.99,
#   'Country': 'EC'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 59.99,
#   'Current Description': 'few clouds',
#   'Humidity': 76,
#   'Cloudiness': 16,
#   'Wind Speed': 8.97,
#   'Country': 'CL'},
#  {'City': 'La Roda',
#   'Lat': 39.2167,
#   'Lng': -2.15,
#   'Max Temp': 96.4,
#   'Current Description': 'clear sky',
#   'Humidity': 15,
#   'Cloudiness': 7,
#   'Wind Speed': 2.73,
#   'Country': 'ES'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.52,
#   'Current Description': 'overcast clouds',
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 7.47,
#   'Country': 'MV'},
#  {'City': 'Geraldton',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 52.21,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'AU'},
#  {'City': 'Ostersund',
#   'Lat': 63.1792,
#   'Lng': 14.6357,
#   'Max Temp': 54.61,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Country': 'SE'},
#  {'City': 'Gobabis',
#   'Lat': -22.45,
#   'Lng': 18.9667,
#   'Max Temp': 57.97,
#   'Current Description': 'few clouds',
#   'Humidity': 37,
#   'Cloudiness': 11,
#   'Wind Speed': 11.14,
#   'Country': 'NA'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 65.48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 17.65,
#   'Country': 'CA'},
#  {'City': 'Nizhniy Baskunchak',
#   'Lat': 48.2198,
#   'Lng': 46.8311,
#   'Max Temp': 73.76,
#   'Current Description': 'clear sky',
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 6.96,
#   'Country': 'RU'},
#  {'City': 'Port Moresby',
#   'Lat': -9.4431,
#   'Lng': 147.1797,
#   'Max Temp': 74.61,
#   'Current Description': 'broken clouds',
#   'Humidity': 91,
#   'Cloudiness': 81,
#   'Wind Speed': 4.32,
#   'Country': 'PG'},
#  {'City': 'Paragominas',
#   'Lat': -2.9667,
#   'Lng': -47.4833,
#   'Max Temp': 91.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Country': 'BR'},
#  {'City': 'Reinosa',
#   'Lat': 42.9996,
#   'Lng': -4.138,
#   'Max Temp': 55.45,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.46,
#   'Country': 'ES'},
#  {'City': 'Mandalgovi',
#   'Lat': 45.7625,
#   'Lng': 106.2708,
#   'Max Temp': 58.98,
#   'Current Description': 'few clouds',
#   'Humidity': 55,
#   'Cloudiness': 15,
#   'Wind Speed': 7.96,
#   'Country': 'MN'},
#  {'City': 'Kidal',
#   'Lat': 18.4411,
#   'Lng': 1.4078,
#   'Max Temp': 101.71,
#   'Current Description': 'overcast clouds',
#   'Humidity': 13,
#   'Cloudiness': 99,
#   'Wind Speed': 7.54,
#   'Country': 'ML'},
#  {'City': 'Kandrian',
#   'Lat': -6.2167,
#   'Lng': 149.55,
#   'Max Temp': 76.17,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.91,
#   'Country': 'PG'},
#  {'City': 'Odda',
#   'Lat': 60.0691,
#   'Lng': 6.5457,
#   'Max Temp': 67.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 3.02,
#   'Country': 'NO'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 55.2,
#   'Current Description': 'broken clouds',
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'NO'},
#  {'City': 'Mangai',
#   'Lat': -4.05,
#   'Lng': 19.5333,
#   'Max Temp': 80.85,
#   'Current Description': 'overcast clouds',
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'CD'},
#  {'City': 'Katobu',
#   'Lat': -4.9408,
#   'Lng': 122.5276,
#   'Max Temp': 71.89,
#   'Current Description': 'few clouds',
#   'Humidity': 88,
#   'Cloudiness': 22,
#   'Wind Speed': 4.05,
#   'Country': 'ID'},
#  {'City': 'Saint George',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 108.79,
#   'Current Description': 'clear sky',
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 54.37,
#   'Current Description': 'few clouds',
#   'Humidity': 93,
#   'Cloudiness': 21,
#   'Wind Speed': 3.27,
#   'Country': 'RU'},
#  {'City': 'Berdigestyakh',
#   'Lat': 62.0989,
#   'Lng': 126.6992,
#   'Max Temp': 59.88,
#   'Current Description': 'overcast clouds',
#   'Humidity': 98,
#   'Cloudiness': 99,
#   'Wind Speed': 1.1,
#   'Country': 'RU'},
#  {'City': 'Sulangan',
#   'Lat': 11.1373,
#   'Lng': 123.7228,
#   'Max Temp': 83.35,
#   'Current Description': 'broken clouds',
#   'Humidity': 77,
#   'Cloudiness': 77,
#   'Wind Speed': 6.49,
#   'Country': 'PH'},
#  {'City': 'Bolgatanga',
#   'Lat': 10.7856,
#   'Lng': -0.8514,
#   'Max Temp': 81.63,
#   'Current Description': 'light rain',
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 3.85,
#   'Country': 'GH'},
#  {'City': 'Alofi',
#   'Lat': -19.0595,
#   'Lng': -169.9187,
#   'Max Temp': 67.89,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 1.14,
#   'Country': 'NU'},
#  {'City': 'Narsaq',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 64.62,
#   'Current Description': 'scattered clouds',
#   'Humidity': 60,
#   'Cloudiness': 32,
#   'Wind Speed': 4.65,
#   'Country': 'GL'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 80.78,
#   'Current Description': 'broken clouds',
#   'Humidity': 46,
#   'Cloudiness': 61,
#   'Wind Speed': 7.92,
#   'Country': 'VE'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': 58.84,
#   'Current Description': 'smoke',
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'CA'},
#  {'City': 'Ketchikan',
#   'Lat': 55.3422,
#   'Lng': -131.6461,
#   'Max Temp': 63.07,
#   'Current Description': 'broken clouds',
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.43,
#   'Current Description': 'scattered clouds',
#   'Humidity': 80,
#   'Cloudiness': 33,
#   'Wind Speed': 8.01,
#   'Country': 'PG'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 54.28,
#   'Current Description': 'overcast clouds',
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 16.17,
#   'Country': 'AU'},
#  {'City': 'Dubai',
#   'Lat': 25.2582,
#   'Lng': 55.3047,
#   'Max Temp': 98.53,
#   'Current Description': 'clear sky',
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'AE'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 58.48,
#   'Current Description': 'overcast clouds',
#   'Humidity': 64,
#   'Cloudiness': 89,
#   'Wind Speed': 4.81,
#   'Country': 'CA'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 70.25,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'MU'},
#  {'City': 'Svobodnyy',
#   'Lat': 51.4,
#   'Lng': 128.1333,
#   'Max Temp': 59.09,
#   'Current Description': 'scattered clouds',
#   'Humidity': 85,
#   'Cloudiness': 29,
#   'Wind Speed': 6.15,
#   'Country': 'RU'},
#  {'City': 'Avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 88.38,
#   'Current Description': 'overcast clouds',
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 9.42,
#   'Country': 'US'},
#  {'City': 'Filadelfia',
#   'Lat': 39.9523,
#   'Lng': -75.1638,
#   'Max Temp': 98.1,
#   'Current Description': 'scattered clouds',
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind Speed': 7,
#   'Country': 'US'},
#  {'City': 'Venice',
#   'Lat': 27.0998,
#   'Lng': -82.4543,
#   'Max Temp': 98.15,
#   'Current Description': 'clear sky',
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 79.92,
#   'Current Description': 'scattered clouds',
#   'Humidity': 80,
#   'Cloudiness': 31,
#   'Wind Speed': 5.97,
#   'Country': 'PG'},
#  {'City': 'Marienburg',
#   'Lat': 54.0359,
#   'Lng': 19.0266,
#   'Max Temp': 71.11,
#   'Current Description': 'clear sky',
#   'Humidity': 84,
#   'Cloudiness': 3,
#   'Wind Speed': 6.87,
#   'Country': 'PL'},
#  {'City': 'Haines Junction',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 50.74,
#   'Current Description': 'overcast clouds',
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 7.02,
#   'Country': 'CA'},
#  {'City': 'Kaniama',
#   'Lat': -7.5667,
#   'Lng': 24.1833,
#   'Max Temp': 75.25,
#   'Current Description': 'broken clouds',
#   'Humidity': 37,
#   'Cloudiness': 54,
#   'Wind Speed': 4.5,
#   'Country': 'CD'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 49.59,
#   'Current Description': 'overcast clouds',
#   'Humidity': 70,
#   'Cloudiness': 98,
#   'Wind Speed': 5.57,
#   'Country': 'AR'},
#  {'City': 'Seidu',
#   'Lat': 9.0167,
#   'Lng': -10.6,
#   'Max Temp': 70.74,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 91,
#   'Wind Speed': 3.11,
#   'Country': 'SL'},
#  {'City': 'Xining',
#   'Lat': 36.6167,
#   'Lng': 101.7667,
#   'Max Temp': 52.07,
#   'Current Description': 'clear sky',
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 1.95,
#   'Country': 'CN'},
#  {'City': 'Kununurra',
#   'Lat': -15.7667,
#   'Lng': 128.7333,
#   'Max Temp': 55.38,
#   'Current Description': 'clear sky',
#   'Humidity': 82,
#   'Cloudiness': 8,
#   'Wind Speed': 1.14,
#   'Country': 'AU'},
#  {'City': 'Pueblo Nuevo',
#   'Lat': 23.3833,
#   'Lng': -105.3833,
#   'Max Temp': 75.94,
#   'Current Description': 'scattered clouds',
#   'Humidity': 49,
#   'Cloudiness': 38,
#   'Wind Speed': 7.81,
#   'Country': 'MX'},
#  {'City': 'Souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 70.07,
#   'Current Description': 'clear sky',
#   'Humidity': 79,
#   'Cloudiness': 2,
#   'Wind Speed': 17.38,
#   'Country': 'MU'},
#  {'City': 'Enna',
#   'Lat': 37.5588,
#   'Lng': 14.2892,
#   'Max Temp': 78.22,
#   'Current Description': 'clear sky',
#   'Humidity': 43,
#   'Cloudiness': 9,
#   'Wind Speed': 2.73,
#   'Country': 'IT'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 36.41,
#   'Current Description': 'few clouds',
#   'Humidity': 93,
#   'Cloudiness': 16,
#   'Wind Speed': 3.58,
#   'Country': 'NZ'},
#  {'City': 'Nacogdoches',
#   'Lat': 31.6002,
#   'Lng': -94.6335,
#   'Max Temp': 91.26,
#   'Current Description': 'clear sky',
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Marsh Harbour',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 84.15,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 15.73,
#   'Country': 'BS'},
#  {'City': 'Bucerias',
#   'Lat': 20.75,
#   'Lng': -105.3333,
#   'Max Temp': 93.97,
#   'Current Description': 'few clouds',
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'MX'},
#  {'City': 'Aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 51.46,
#   'Current Description': 'clear sky',
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 2.66,
#   'Country': 'RU'},
#  {'City': 'Harboore',
#   'Lat': 56.6175,
#   'Lng': 8.1807,
#   'Max Temp': 58.17,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 11.68,
#   'Country': 'DK'},
#  {'City': 'Itarema',
#   'Lat': -2.9248,
#   'Lng': -39.9167,
#   'Max Temp': 84.43,
#   'Current Description': 'broken clouds',
#   'Humidity': 65,
#   'Cloudiness': 82,
#   'Wind Speed': 17.27,
#   'Country': 'BR'},
#  {'City': 'Batemans Bay',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 51.1,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 19,
#   'Wind Speed': 5.12,
#   'Country': 'AU'},
#  {'City': 'Hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 52.34,
#   'Current Description': 'scattered clouds',
#   'Humidity': 92,
#   'Cloudiness': 47,
#   'Wind Speed': 7.9,
#   'Country': 'IS'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 65.79,
#   'Current Description': 'light rain',
#   'Humidity': 83,
#   'Cloudiness': 45,
#   'Wind Speed': 13.13,
#   'Country': 'RE'},
#  {'City': 'Yibin',
#   'Lat': 28.7667,
#   'Lng': 104.6238,
#   'Max Temp': 69.1,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'CN'},
#  {'City': 'Hecun',
#   'Lat': 36.5333,
#   'Lng': 114.1111,
#   'Max Temp': 69.1,
#   'Current Description': 'broken clouds',
#   'Humidity': 84,
#   'Cloudiness': 71,
#   'Wind Speed': 4.29,
#   'Country': 'CN'},
#  {'City': 'Muzhi',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': 47.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 10.85,
#   'Country': 'RU'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 75.63,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 99,
#   'Wind Speed': 3.51,
#   'Country': 'ID'},
#  {'City': 'Waddan',
#   'Lat': 29.1614,
#   'Lng': 16.139,
#   'Max Temp': 85.53,
#   'Current Description': 'clear sky',
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 8.1,
#   'Country': 'LY'},
#  {'City': 'Ketou',
#   'Lat': 7.3633,
#   'Lng': 2.5998,
#   'Max Temp': 74.86,
#   'Current Description': 'light rain',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'BJ'},
#  {'City': 'Mandapam',
#   'Lat': 9.2833,
#   'Lng': 79.1167,
#   'Max Temp': 81.79,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.02,
#   'Country': 'IN'},
#  {'City': 'Winnemucca',
#   'Lat': 40.973,
#   'Lng': -117.7357,
#   'Max Temp': 91.45,
#   'Current Description': 'clear sky',
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 74.68,
#   'Current Description': 'clear sky',
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 13.82,
#   'Country': 'ES'},
#  {'City': 'Bethel',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 95.04,
#   'Current Description': 'clear sky',
#   'Humidity': 39,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 62.53,
#   'Current Description': 'few clouds',
#   'Humidity': 89,
#   'Cloudiness': 15,
#   'Wind Speed': 6.04,
#   'Country': 'AO'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 55.29,
#   'Current Description': 'light rain',
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 58.42,
#   'Current Description': 'overcast clouds',
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.79,
#   'Country': 'UY'},
#  {'City': 'Praia',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 79.34,
#   'Current Description': 'scattered clouds',
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'CV'},
#  {'City': 'Sharlyk',
#   'Lat': 52.9167,
#   'Lng': 54.75,
#   'Max Temp': 64.26,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 7.63,
#   'Country': 'RU'},
#  {'City': 'Arzgir',
#   'Lat': 45.3728,
#   'Lng': 44.2206,
#   'Max Temp': 70.36,
#   'Current Description': 'light rain',
#   'Humidity': 62,
#   'Cloudiness': 97,
#   'Wind Speed': 11.5,
#   'Country': 'RU'},
#  {'City': 'Marsa Matruh',
#   'Lat': 31.3525,
#   'Lng': 27.2453,
#   'Max Temp': 78.58,
#   'Current Description': 'clear sky',
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 10.65,
#   'Country': 'EG'},
#  {'City': 'Traverse City',
#   'Lat': 44.7631,
#   'Lng': -85.6206,
#   'Max Temp': 90,
#   'Current Description': 'few clouds',
#   'Humidity': 31,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Country': 'US'},
#  {'City': 'Dutse',
#   'Lat': 11.7594,
#   'Lng': 9.3392,
#   'Max Temp': 80.92,
#   'Current Description': 'overcast clouds',
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 9.98,
#   'Country': 'NG'},
#  {'City': 'Laurel',
#   'Lat': 39.0993,
#   'Lng': -76.8483,
#   'Max Temp': 97.61,
#   'Current Description': 'clear sky',
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'US'},
#  {'City': 'Lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 72.81,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Country': 'PT'},
#  {'City': 'Okoneshnikovo',
#   'Lat': 54.8377,
#   'Lng': 75.0834,
#   'Max Temp': 57.06,
#   'Current Description': 'scattered clouds',
#   'Humidity': 78,
#   'Cloudiness': 43,
#   'Wind Speed': 6.85,
#   'Country': 'RU'},
#  {'City': 'Biak',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 75.52,
#   'Current Description': 'broken clouds',
#   'Humidity': 88,
#   'Cloudiness': 59,
#   'Wind Speed': 7.16,
#   'Country': 'ID'},
#  {'City': 'Barsovo',
#   'Lat': 61.1667,
#   'Lng': 73.1667,
#   'Max Temp': 51.93,
#   'Current Description': 'clear sky',
#   'Humidity': 69,
#   'Cloudiness': 7,
#   'Wind Speed': 4.03,
#   'Country': 'RU'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 78.6,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 16.35,
#   'Country': 'BR'},
#  {'City': 'Lluta',
#   'Lat': -16.0147,
#   'Lng': -72.0142,
#   'Max Temp': 62.24,
#   'Current Description': 'clear sky',
#   'Humidity': 21,
#   'Cloudiness': 0,
#   'Wind Speed': 11.21,
#   'Country': 'PE'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 69.8,
#   'Current Description': 'broken clouds',
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 78.12,
#   'Current Description': 'clear sky',
#   'Humidity': 80,
#   'Cloudiness': 8,
#   'Wind Speed': 6.78,
#   'Country': 'PG'},
#  {'City': 'Kutum',
#   'Lat': 14.2,
#   'Lng': 24.6667,
#   'Max Temp': 84.97,
#   'Current Description': 'clear sky',
#   'Humidity': 31,
#   'Cloudiness': 4,
#   'Wind Speed': 7.47,
#   'Country': 'SD'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 84.22,
#   'Current Description': 'few clouds',
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 20.71,
#   'Country': 'US'},
#  {'City': 'Black Diamond',
#   'Lat': 47.3087,
#   'Lng': -122.0032,
#   'Max Temp': 68.02,
#   'Current Description': 'broken clouds',
#   'Humidity': 72,
#   'Cloudiness': 80,
#   'Wind Speed': 3,
#   'Country': 'US'},
#  {'City': 'Ambulu',
#   'Lat': -8.345,
#   'Lng': 113.6058,
#   'Max Temp': 72.91,
#   'Current Description': 'broken clouds',
#   'Humidity': 88,
#   'Cloudiness': 59,
#   'Wind Speed': 3.31,
#   'Country': 'ID'},
#  {'City': 'Padrauna',
#   'Lat': 26.9025,
#   'Lng': 83.9819,
#   'Max Temp': 82.81,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 9.93,
#   'Country': 'IN'},
#  {'City': 'Nanpiao',
#   'Lat': 41.0982,
#   'Lng': 120.7479,
#   'Max Temp': 73.36,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.88,
#   'Country': 'CN'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 57.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 95,
#   'Wind Speed': 4.56,
#   'Country': 'CA'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.7333,
#   'Lng': -25.6667,
#   'Max Temp': 72.32,
#   'Current Description': 'few clouds',
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'PT'},
#  {'City': 'Ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 65.57,
#   'Current Description': 'clear sky',
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 4.79,
#   'Country': 'MG'},
#  {'City': 'Kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 76.69,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 5,
#   'Wind Speed': 3.87,
#   'Country': 'PG'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 55.35,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Country': 'US'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 77.04,
#   'Current Description': 'overcast clouds',
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'IN'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 54.19,
#   'Current Description': 'broken clouds',
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 0,
#   'Country': 'RU'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 74.17,
#   'Current Description': 'broken clouds',
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CA'},
#  {'City': 'Erzin',
#   'Lat': 36.9559,
#   'Lng': 36.2,
#   'Max Temp': 77.14,
#   'Current Description': 'clear sky',
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 3.04,
#   'Country': 'TR'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 60.98,
#   'Current Description': 'broken clouds',
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA'},
#  {'City': 'Cardston',
#   'Lat': 49.2,
#   'Lng': -113.3019,
#   'Max Temp': 64.69,
#   'Current Description': 'overcast clouds',
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'CA'},
#  {'City': 'Isla Mujeres',
#   'Lat': 21.2311,
#   'Lng': -86.731,
#   'Max Temp': 82.45,
#   'Current Description': 'scattered clouds',
#   'Humidity': 67,
#   'Cloudiness': 28,
#   'Wind Speed': 11.23,
#   'Country': 'MX'},
#  {'City': 'Gillette',
#   'Lat': 44.2911,
#   'Lng': -105.5022,
#   'Max Temp': 98.11,
#   'Current Description': 'clear sky',
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 14,
#   'Country': 'US'},
#  {'City': 'Clyde River',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 55.63,
#   'Current Description': 'broken clouds',
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Country': 'CA'},
#  {'City': 'Margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 64.9,
#   'Current Description': 'broken clouds',
#   'Humidity': 79,
#   'Cloudiness': 71,
#   'Wind Speed': 4,
#   'Country': 'GB'},
#  {'City': 'Prescott',
#   'Lat': 34.54,
#   'Lng': -112.4685,
#   'Max Temp': 97.27,
#   'Current Description': 'clear sky',
#   'Humidity': 23,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Tonj',
#   'Lat': 7.2737,
#   'Lng': 28.6822,
#   'Max Temp': 71.89,
#   'Current Description': 'moderate rain',
#   'Humidity': 93,
#   'Cloudiness': 13,
#   'Wind Speed': 3.69,
#   'Country': 'SS'},
#  {'City': 'Lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 75.31,
#   'Current Description': 'few clouds',
#   'Humidity': 48,
#   'Cloudiness': 12,
#   'Wind Speed': 5.86,
#   'Country': 'PT'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 78.26,
#   'Current Description': 'light rain',
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.04,
#   'Country': 'ID'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 53.92,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 12.15,
#   'Country': 'CL'},
#  {'City': 'Katangli',
#   'Lat': 51.7102,
#   'Lng': 143.2326,
#   'Max Temp': 50.88,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.34,
#   'Country': 'RU'},
#  {'City': 'Fougamou',
#   'Lat': -1.2154,
#   'Lng': 10.5838,
#   'Max Temp': 81.34,
#   'Current Description': 'overcast clouds',
#   'Humidity': 54,
#   'Cloudiness': 94,
#   'Wind Speed': 5.73,
#   'Country': 'GA'},
#  {'City': 'Lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 77.88,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 59,
#   'Wind Speed': 3.8,
#   'Country': 'IT'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 50,
#   'Current Description': 'few clouds',
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Country': 'CA'},
#  {'City': 'Rundu',
#   'Lat': -17.9333,
#   'Lng': 19.7667,
#   'Max Temp': 63.61,
#   'Current Description': 'few clouds',
#   'Humidity': 42,
#   'Cloudiness': 16,
#   'Wind Speed': 7,
#   'Country': 'NA'},
#  {'City': 'Lima',
#   'Lat': -12.0432,
#   'Lng': -77.0282,
#   'Max Temp': 69.91,
#   'Current Description': 'overcast clouds',
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 4.61,
#   'Country': 'PE'},
#  {'City': 'Koungou',
#   'Lat': -12.7336,
#   'Lng': 45.2042,
#   'Max Temp': 73.11,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'YT'},
#  {'City': 'Michigan City',
#   'Lat': 41.7075,
#   'Lng': -86.895,
#   'Max Temp': 90.05,
#   'Current Description': 'clear sky',
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'US'},
#  {'City': 'Cam Ranh',
#   'Lat': 11.9214,
#   'Lng': 109.1591,
#   'Max Temp': 76.96,
#   'Current Description': 'few clouds',
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'VN'},
#  {'City': 'Bilasipara',
#   'Lat': 26.232,
#   'Lng': 90.2347,
#   'Max Temp': 81.59,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.71,
#   'Country': 'IN'},
#  {'City': 'Maputo',
#   'Lat': -25.9653,
#   'Lng': 32.5892,
#   'Max Temp': 64.08,
#   'Current Description': 'scattered clouds',
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 5.75,
#   'Country': 'MZ'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 51.75,
#   'Current Description': 'overcast clouds',
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 2.37,
#   'Country': 'TL'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 73.27,
#   'Current Description': 'overcast clouds',
#   'Humidity': 45,
#   'Cloudiness': 91,
#   'Wind Speed': 7.96,
#   'Country': 'CA'},
#  {'City': 'Rafsanjan',
#   'Lat': 30.4067,
#   'Lng': 55.9939,
#   'Max Temp': 90.3,
#   'Current Description': 'clear sky',
#   'Humidity': 10,
#   'Cloudiness': 6,
#   'Wind Speed': 4.72,
#   'Country': 'IR'},
#  {'City': 'Caninde De Sao Francisco',
#   'Lat': -9.66,
#   'Lng': -37.7894,
#   'Max Temp': 78.4,
#   'Current Description': 'broken clouds',
#   'Humidity': 66,
#   'Cloudiness': 79,
#   'Wind Speed': 10.31,
#   'Country': 'BR'},
#  {'City': 'Henties Bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 61.11,
#   'Current Description': 'clear sky',
#   'Humidity': 66,
# ...
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Country': 'IN'},
#  {'City': 'Inhambane',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 62.58,
#   'Current Description': 'few clouds',
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 0,
#   'Country': 'MZ'},
#  {'City': 'Sijunjung',
#   'Lat': -0.6876,
#   'Lng': 100.9537,
#   'Max Temp': 72.66,
#   'Current Description': 'overcast clouds',
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.2,
#   'Country': 'ID'},
#  {'City': 'Lufilufi',
#   'Lat': -13.8745,
#   'Lng': -171.5986,
#   'Max Temp': 74.98,
#   'Current Description': 'light rain',
#   'Humidity': 78,
#   'Cloudiness': 24,
#   'Wind Speed': 9.89,
#   'Country': 'WS'},
#  {'City': 'Tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 91.09,
#   'Current Description': 'few clouds',
#   'Humidity': 23,
#   'Cloudiness': 11,
#   'Wind Speed': 4.14,
#   'Country': 'MA'},
#  {'City': 'Taganak',
#   'Lat': 6.0833,
#   'Lng': 118.3,
#   'Max Temp': 78.94,
#   'Current Description': 'overcast clouds',
#   'Humidity': 72,
#   'Cloudiness': 93,
#   'Wind Speed': 3.47,
#   'Country': 'PH'},
#  {'City': 'Tha Mai',
#   'Lat': 12.6214,
#   'Lng': 102.0048,
#   'Max Temp': 83.05,
#   'Current Description': 'overcast clouds',
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 4,
#   'Country': 'TH'},
#  {'City': 'Ascension',
#   'Lat': 30.2169,
#   'Lng': -90.9001,
#   'Max Temp': 91.99,
#   'Current Description': 'broken clouds',
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'US'},
#  {'City': 'Grindavik',
#   'Lat': 63.8424,
#   'Lng': -22.4338,
#   'Max Temp': 55.87,
#   'Current Description': 'broken clouds',
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'IS'},
#  {'City': 'Celestun',
#   'Lat': 20.8667,
#   'Lng': -90.4,
#   'Max Temp': 87.46,
#   'Current Description': 'scattered clouds',
#   'Humidity': 64,
#   'Cloudiness': 30,
#   'Wind Speed': 12.46,
#   'Country': 'MX'},
#  {'City': 'Ulkan',
#   'Lat': 57.243,
#   'Lng': 107.3223,
#   'Max Temp': 59.02,
#   'Current Description': 'broken clouds',
#   'Humidity': 99,
#   'Cloudiness': 68,
#   'Wind Speed': 2.53,
#   'Country': 'RU'},
#  {'City': 'Dabat',
#   'Lat': 12.9842,
#   'Lng': 37.765,
#   'Max Temp': 55.09,
#   'Current Description': 'scattered clouds',
#   'Humidity': 91,
#   'Cloudiness': 34,
#   'Wind Speed': 1.41,
#   'Country': 'ET'},
#  {'City': 'Binzhou',
#   'Lat': 37.3667,
#   'Lng': 118.0167,
#   'Max Temp': 69.04,
#   'Current Description': 'overcast clouds',
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 5.64,
#   'Country': 'CN'},
#  {'City': 'Artvin',
#   'Lat': 41.1667,
#   'Lng': 41.8333,
#   'Max Temp': 57.31,
#   'Current Description': 'few clouds',
#   'Humidity': 93,
#   'Cloudiness': 16,
#   'Wind Speed': 2.08,
#   'Country': 'TR'},
#  {'City': 'Voskresenskoye',
#   'Lat': 56.8381,
#   'Lng': 45.4317,
#   'Max Temp': 63.48,
#   'Current Description': 'broken clouds',
#   'Humidity': 72,
#   'Cloudiness': 51,
#   'Wind Speed': 2.86,
#   'Country': 'RU'},
#  {'City': 'Ialibu',
#   'Lat': -6.2821,
#   'Lng': 143.9935,
#   'Max Temp': 52.34,
#   'Current Description': 'few clouds',
#   'Humidity': 95,
#   'Cloudiness': 16,
#   'Wind Speed': 2.48,
#   'Country': 'PG'},
#  {'City': 'Gazanjyk',
#   'Lat': 39.2446,
#   'Lng': 55.5154,
#   'Max Temp': 80.58,
#   'Current Description': 'clear sky',
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 15.05,
#   'Country': 'TM'},
#  {'City': 'Santa Cruz Del Sur',
#   'Lat': 20.7147,
#   'Lng': -77.9956,
#   'Max Temp': 87.84,
#   'Current Description': 'scattered clouds',
#   'Humidity': 64,
#   'Cloudiness': 45,
#   'Wind Speed': 6.46,
#   'Country': 'CU'},
#  {'City': 'Kapoeta',
#   'Lat': 4.7717,
#   'Lng': 33.5903,
#   'Max Temp': 84.83,
#   'Current Description': 'overcast clouds',
#   'Humidity': 37,
#   'Cloudiness': 97,
#   'Wind Speed': 11.48,
#   'Country': 'SS'},
#  {'City': 'Cedar City',
#   'Lat': 37.6775,
#   'Lng': -113.0619,
#   'Max Temp': 95.97,
#   'Current Description': 'clear sky',
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 14.97,
#   'Country': 'US'},
#  {'City': 'Hailar',
#   'Lat': 49.2,
#   'Lng': 119.7,
#   'Max Temp': 63.97,
#   'Current Description': 'few clouds',
#   'Humidity': 84,
#   'Cloudiness': 23,
#   'Wind Speed': 8.12,
#   'Country': 'CN'},
#  {'City': 'Soyalo',
#   'Lat': 16.9,
#   'Lng': -92.9167,
#   'Max Temp': 74.3,
#   'Current Description': 'overcast clouds',
#   'Humidity': 58,
#   'Cloudiness': 92,
#   'Wind Speed': 2.06,
#   'Country': 'MX'},
#  {'City': 'Montivilliers',
#   'Lat': 49.5452,
#   'Lng': 0.1877,
#   'Max Temp': 68.77,
#   'Current Description': 'broken clouds',
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'FR'},
#  {'City': 'Popondetta',
#   'Lat': -8.7537,
#   'Lng': 148.2534,
#   'Max Temp': 73.13,
#   'Current Description': 'scattered clouds',
#   'Humidity': 90,
#   'Cloudiness': 26,
#   'Wind Speed': 2.48,
#   'Country': 'PG'},
#  {'City': 'Hobyo',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 76.3,
#   'Current Description': 'few clouds',
#   'Humidity': 81,
#   'Cloudiness': 11,
#   'Wind Speed': 22.95,
#   'Country': 'SO'},
#  {'City': 'Malia',
#   'Lat': 35.2833,
#   'Lng': 25.4667,
#   'Max Temp': 84.81,
#   'Current Description': 'clear sky',
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 7,
#   'Country': 'GR'},
#  {'City': 'Yarkovo',
#   'Lat': 57.4028,
#   'Lng': 67.0786,
#   'Max Temp': 55.47,
#   'Current Description': 'few clouds',
#   'Humidity': 93,
#   'Cloudiness': 11,
#   'Wind Speed': 4.23,
#   'Country': 'RU'},
#  {'City': 'Sajanan',
#   'Lat': 37.0573,
#   'Lng': 9.2426,
#   'Max Temp': 88.72,
#   'Current Description': 'clear sky',
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 8.7,
#   'Country': 'TN'},
#  {'City': 'Raymond Terrace',
#   'Lat': -32.75,
#   'Lng': 151.75,
#   'Max Temp': 60.01,
#   'Current Description': 'broken clouds',
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'AU'},
#  {'City': 'Amethi',
#   'Lat': 26.15,
#   'Lng': 81.8167,
#   'Max Temp': 85.35,
#   'Current Description': 'overcast clouds',
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Country': 'IN'},
#  {'City': 'Maarianhamina',
#   'Lat': 60.0973,
#   'Lng': 19.9348,
#   'Max Temp': 66.06,
#   'Current Description': 'overcast clouds',
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'AX'},
#  {'City': 'Wangaratta',
#   'Lat': -36.3667,
#   'Lng': 146.3333,
#   'Max Temp': 44.31,
#   'Current Description': 'light rain',
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Country': 'AU'},
#  {'City': 'Sendai',
#   'Lat': 38.2689,
#   'Lng': 140.8719,
#   'Max Temp': 70.9,
#   'Current Description': 'few clouds',
#   'Humidity': 96,
#   'Cloudiness': 20,
#   'Wind Speed': 2.24,
#   'Country': 'JP'},
#  {'City': 'Dunedin',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 43.81,
#   'Current Description': 'few clouds',
#   'Humidity': 80,
#   'Cloudiness': 16,
#   'Wind Speed': 5.99,
#   'Country': 'NZ'},
#  {'City': 'Springbok',
#   'Lat': -29.6643,
#   'Lng': 17.8865,
#   'Max Temp': 54,
#   'Current Description': 'overcast clouds',
#   'Humidity': 48,
#   'Cloudiness': 100,
#   'Wind Speed': 3.2,
#   'Country': 'ZA'},
#  {'City': 'Yairipok',
#   'Lat': 24.6667,
#   'Lng': 94.0667,
#   'Max Temp': 70.97,
#   'Current Description': 'overcast clouds',
#   'Humidity': 92,
#   'Cloudiness': 89,
#   'Wind Speed': 0.16,
#   'Country': 'IN'},
#  {'City': 'Bethanien',
#   'Lat': -26.502,
#   'Lng': 17.1583,
#   'Max Temp': 62.1,
#   'Current Description': 'few clouds',
#   'Humidity': 27,
#   'Cloudiness': 14,
#   'Wind Speed': 2.08,
#   'Country': 'NA'},
#  {'City': 'Hervey Bay',
#   'Lat': -25.2986,
#   'Lng': 152.8535,
#   'Max Temp': 63.23,
#   'Current Description': 'overcast clouds',
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 19.8,
#   'Country': 'AU'},
#  {'City': 'Kyra',
#   'Lat': 49.5776,
#   'Lng': 111.9753,
#   'Max Temp': 57.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 0.09,
#   'Country': 'RU'},
#  {'City': 'Vung Tau',
#   'Lat': 10.346,
#   'Lng': 107.0843,
#   'Max Temp': 80.38,
#   'Current Description': 'overcast clouds',
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.85,
#   'Country': 'VN'},
#  {'City': 'Dudinka',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': 63.63,
#   'Current Description': 'broken clouds',
#   'Humidity': 68,
#   'Cloudiness': 81,
#   'Wind Speed': 8.43,
#   'Country': 'RU'},
#  {'City': 'Kyaukse',
#   'Lat': 21.6,
#   'Lng': 96.1333,
#   'Max Temp': 77.58,
#   'Current Description': 'overcast clouds',
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.71,
#   'Country': 'MM'},
#  {'City': 'Shieli',
#   'Lat': 44.1667,
#   'Lng': 66.75,
#   'Max Temp': 90.99,
#   'Current Description': 'clear sky',
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 14.79,
#   'Country': 'KZ'},
#  {'City': 'Gazli',
#   'Lat': 40.1333,
#   'Lng': 63.45,
#   'Max Temp': 98.04,
#   'Current Description': 'clear sky',
#   'Humidity': 13,
#   'Cloudiness': 0,
#   'Wind Speed': 11.86,
#   'Country': 'UZ'},
#  {'City': 'Ajdabiya',
#   'Lat': 30.7554,
#   'Lng': 20.2263,
#   'Max Temp': 78.96,
#   'Current Description': 'clear sky',
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 19.04,
#   'Country': 'LY'},
#  {'City': 'Korba',
#   'Lat': 22.35,
#   'Lng': 82.6833,
#   'Max Temp': 79.3,
#   'Current Description': 'light rain',
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'IN'},
#  {'City': 'Jodhpur',
#   'Lat': 26.2867,
#   'Lng': 73.03,
#   'Max Temp': 84.92,
#   'Current Description': 'overcast clouds',
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 9.13,
#   'Country': 'IN'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 76.39,
#   'Current Description': 'clear sky',
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 11.07,
#   'Country': 'CN'},
#  {'City': 'Porto Torres',
#   'Lat': 40.835,
#   'Lng': 8.3972,
#   'Max Temp': 84.38,
#   'Current Description': 'clear sky',
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.51,
#   'Country': 'IT'},
#  {'City': 'Ndola',
#   'Lat': -12.9587,
#   'Lng': 28.6366,
#   'Max Temp': 64.74,
#   'Current Description': 'broken clouds',
#   'Humidity': 45,
#   'Cloudiness': 69,
#   'Wind Speed': 8.55,
#   'Country': 'ZM'},
#  {'City': 'Staszow',
#   'Lat': 50.5631,
#   'Lng': 21.1659,
#   'Max Temp': 79.5,
#   'Current Description': 'broken clouds',
#   'Humidity': 79,
#   'Cloudiness': 71,
#   'Wind Speed': 9.13,
#   'Country': 'PL'},
#  {'City': 'San Quintin',
#   'Lat': 30.4833,
#   'Lng': -115.95,
#   'Max Temp': 73.98,
#   'Current Description': 'overcast clouds',
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 16.75,
#   'Country': 'MX'},
#  {'City': 'Morondava',
#   'Lat': -20.2833,
#   'Lng': 44.2833,
#   'Max Temp': 72.32,
#   'Current Description': 'clear sky',
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 13.35,
#   'Country': 'MG'},
#  {'City': 'Ishigaki',
#   'Lat': 24.3448,
#   'Lng': 124.1572,
#   'Max Temp': 82.53,
#   'Current Description': 'few clouds',
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'JP'},
#  {'City': 'Asau',
#   'Lat': 46.4333,
#   'Lng': 26.4,
#   'Max Temp': 74.32,
#   'Current Description': 'clear sky',
#   'Humidity': 52,
#   'Cloudiness': 5,
#   'Wind Speed': 5.12,
#   'Country': 'RO'},
#  {'City': 'Arfara',
#   'Lat': 37.15,
#   'Lng': 22.0333,
#   'Max Temp': 83.95,
#   'Current Description': 'clear sky',
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'GR'},
#  {'City': 'Kaoma',
#   'Lat': -14.7833,
#   'Lng': 24.8,
#   'Max Temp': 61.48,
#   'Current Description': 'clear sky',
#   'Humidity': 45,
#   'Cloudiness': 3,
#   'Wind Speed': 5.44,
#   'Country': 'ZM'},
#  {'City': 'Garhi Yasin',
#   'Lat': 27.9069,
#   'Lng': 68.511,
#   'Max Temp': 84.22,
#   'Current Description': 'overcast clouds',
#   'Humidity': 58,
#   'Cloudiness': 98,
#   'Wind Speed': 9.15,
#   'Country': 'PK'},
#  {'City': 'Paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 45.5,
#   'Current Description': 'clear sky',
#   'Humidity': 84,
#   'Cloudiness': 6,
#   'Wind Speed': 6.06,
#   'Country': 'GL'},
#  {'City': 'Crixas',
#   'Lat': -14.5489,
#   'Lng': -49.9692,
#   'Max Temp': 91.42,
#   'Current Description': 'clear sky',
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 5.12,
#   'Country': 'BR'},
#  {'City': 'Deer Lake',
#   'Lat': 49.1667,
#   'Lng': -57.4316,
#   'Max Temp': 82.26,
#   'Current Description': 'broken clouds',
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'CA'},
#  {'City': 'Balkanabat',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 81.23,
#   'Current Description': 'clear sky',
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 8.32,
#   'Country': 'TM'},
#  {'City': 'Ganzhou',
#   'Lat': 28.8184,
#   'Lng': 115.4327,
#   'Max Temp': 81.73,
#   'Current Description': 'broken clouds',
#   'Humidity': 77,
#   'Cloudiness': 71,
#   'Wind Speed': 4.88,
#   'Country': 'CN'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 96.3,
#   'Current Description': 'clear sky',
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Country': 'US'},
#  {'City': 'Vangaindrano',
#   'Lat': -23.35,
#   'Lng': 47.6,
#   'Max Temp': 64.92,
#   'Current Description': 'light rain',
#   'Humidity': 87,
#   'Cloudiness': 15,
#   'Wind Speed': 2.42,
#   'Country': 'MG'},
#  {'City': 'Kirakira',
#   'Lat': -10.4544,
#   'Lng': 161.9205,
#   'Max Temp': 77.14,
#   'Current Description': 'broken clouds',
#   'Humidity': 84,
#   'Cloudiness': 76,
#   'Wind Speed': 3.87,
#   'Country': 'SB'},
#  {'City': 'Takefu',
#   'Lat': 35.9039,
#   'Lng': 136.1669,
#   'Max Temp': 71.4,
#   'Current Description': 'overcast clouds',
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'JP'},
#  {'City': 'Pudozh',
#   'Lat': 61.8099,
#   'Lng': 36.5345,
#   'Max Temp': 65.53,
#   'Current Description': 'overcast clouds',
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 4.12,
#   'Country': 'RU'},
#  {'City': 'Cabatuan',
#   'Lat': 10.8794,
#   'Lng': 122.486,
#   'Max Temp': 76.12,
#   'Current Description': 'moderate rain',
#   'Humidity': 91,
#   'Cloudiness': 85,
#   'Wind Speed': 5.39,
#   'Country': 'PH'},
#  {'City': 'Mehran',
#   'Lat': 33.1222,
#   'Lng': 46.1646,
#   'Max Temp': 97.72,
#   'Current Description': 'clear sky',
#   'Humidity': 12,
#   'Cloudiness': 0,
#   'Wind Speed': 14.23,
#   'Country': 'IR'},
#  {'City': 'Omboue',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 71.2,
#   'Current Description': 'broken clouds',
#   'Humidity': 81,
#   'Cloudiness': 78,
#   'Wind Speed': 11.48,
#   'Country': 'GA'},
#  {'City': 'Navoi',
#   'Lat': 40.0844,
#   'Lng': 65.3792,
#   'Max Temp': 87.28,
#   'Current Description': 'clear sky',
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 0,
#   'Country': 'UZ'},
#  {'City': 'Vaitape',
#   'Lat': -16.5167,
#   'Lng': -151.75,
#   'Max Temp': 77.9,
#   'Current Description': 'light rain',
#   'Humidity': 74,
#   'Cloudiness': 16,
#   'Wind Speed': 9.93,
#   'Country': 'PF'},
#  {'City': 'Oyama',
#   'Lat': 36.3,
#   'Lng': 139.8,
#   'Max Temp': 84.58,
#   'Current Description': 'broken clouds',
#   'Humidity': 93,
#   'Cloudiness': 84,
#   'Wind Speed': 4.54,
#   'Country': 'JP'},
#  {'City': 'Alihe',
#   'Lat': 50.5667,
#   'Lng': 123.7167,
#   'Max Temp': 60.49,
#   'Current Description': 'few clouds',
#   'Humidity': 96,
#   'Cloudiness': 14,
#   'Wind Speed': 2.68,
#   'Country': 'CN'},
#  {'City': 'Zhigansk',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 52.36,
#   'Current Description': 'light rain',
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 8.23,
#   'Country': 'RU'},
#  {'City': 'Muborak',
#   'Lat': 39.2553,
#   'Lng': 65.1528,
#   'Max Temp': 93.56,
#   'Current Description': 'clear sky',
#   'Humidity': 9,
#   'Cloudiness': 0,
#   'Wind Speed': 11.12,
#   'Country': 'UZ'},
#  {'City': 'Rawlins',
#   'Lat': 41.7911,
#   'Lng': -107.2387,
#   'Max Temp': 87.69,
#   'Current Description': 'clear sky',
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Country': 'US'},
#  {'City': 'Skibbereen',
#   'Lat': 51.55,
#   'Lng': -9.2667,
#   'Max Temp': 62.11,
#   'Current Description': 'overcast clouds',
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.52,
#   'Country': 'IE'},
#  {'City': 'Bahia Blanca',
#   'Lat': -38.7196,
#   'Lng': -62.2724,
#   'Max Temp': 54.14,
#   'Current Description': 'light rain',
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 5.99,
#   'Country': 'AR'},
#  {'City': 'Suntar',
#   'Lat': 62.1444,
#   'Lng': 117.6319,
#   'Max Temp': 58.32,
#   'Current Description': 'overcast clouds',
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Country': 'RU'}]

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp Current Description  \
# 0             Langsa   4.4683   97.9683     74.07     overcast clouds
# 1         Hambantota   6.1241   81.1185     79.20     overcast clouds
# 2  Sao Joao Da Barra -21.6403  -41.0511     78.89           clear sky
# 3       San Patricio  28.0170  -97.5169     98.17           clear sky
# 4             Wanaka -44.7000  169.1500     22.17          few clouds
# 5             Hobart -42.8794  147.3294     50.25     overcast clouds
# 6            Labuhan  -6.8844  112.2051     75.29       broken clouds
# 7        Mujiayingzi  42.1167  118.7833     66.40     overcast clouds
# 8           Cidreira -30.1811  -50.2056     66.67          light rain
# 9            Ushuaia -54.8000  -68.3000     33.46               sleet
#
#    Humidity  Cloudiness  Wind Speed Country
# 0        96          92        2.77      ID
# 1        82          95       17.69      LK
# 2        75           0       13.91      BR
# 3        42           4       17.31      US
# 4        92          23        2.75      NZ
# 5        84         100        8.05      AU
# 6        84          55        7.67      ID
# 7        86         100        3.91      CN
# 8        87         100        4.00      BR
# 9       100         100       23.02      AR

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
