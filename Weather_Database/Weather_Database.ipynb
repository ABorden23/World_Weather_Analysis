# %%
# Import dependencies.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
import os

#Add Citipy Imprt Citipy
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config_weather_database import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

cities
# Out:
# ['mercedes',
#  'jamestown',
#  'torva',
#  'jiddah',
#  'pisco',
#  'hermanus',
#  'srednekolymsk',
#  'vaini',
#  'rikitea',
#  'qaanaaq',
#  'iquique',
#  'kapaa',
#  'mount gambier',
#  'punta arenas',
#  'colonelganj',
#  'sao joao da barra',
#  'gamba',
#  'umm lajj',
#  'kangaatsiaq',
#  'sao jose do belmonte',
#  'port lincoln',
#  'grand river south east',
#  'yuzhno-yeniseyskiy',
#  'port alfred',
#  'melilla',
#  'atuona',
#  'nampula',
#  'victoria',
#  'clyde river',
#  'jacqueville',
#  'baghdad',
#  'carnarvon',
#  'airai',
#  'vila velha',
#  'chapayevka',
#  'lakeside',
#  'kodiak',
#  'nhulunbuy',
#  'kavieng',
#  'lebu',
#  'rio grande',
#  'hoorn',
#  'ushuaia',
#  'de-kastri',
#  'tabulbah',
#  'pandan',
#  'barrow',
#  'hobart',
#  'saint-joseph',
#  'upernavik',
#  'lekoni',
#  'tuktoyaktuk',
#  'liloan',
#  'mataura',
#  'lolua',
#  'chokurdakh',
#  'salinas',
#  'nikolskoye',
#  'saint-philippe',
#  'le marin',
#  'taolanaro',
#  'the valley',
#  'svetlyy',
#  'beloha',
#  'longlac',
#  'umzimvubu',
#  'adrar',
#  'flinders',
#  'talnakh',
#  'mumbwa',
#  'new norfolk',
#  'tehuantepec',
#  'caninde',
#  'penzance',
#  'dubti',
#  'urucara',
#  'thompson',
#  'alofi',
#  'road town',
#  'tolaga bay',
#  'codrington',
#  'belushya guba',
#  'provideniya',
#  'puerto ayora',
#  'saint-pierre',
#  'georgetown',
#  'leningradskiy',
#  'leua',
#  'yellowknife',
#  'oksfjord',
#  'batagay-alyta',
#  'sarangani',
#  'nicoya',
#  'kozhva',
#  'mys shmidta',
#  'arraial do cabo',
#  'pedernales',
#  'manicore',
#  'nanortalik',
#  'chuy',
#  'bluff',
#  'mashhad',
#  'busselton',
#  'gerash',
#  'bonavista',
#  'castro',
#  'port blair',
#  'kahului',
#  'bredasdorp',
#  'ponta do sol',
#  'muros',
#  'sumbawa',
#  'baykit',
#  'palmer',
#  'saleaula',
#  'dubai',
#  'butaritari',
#  'albany',
#  'saskylakh',
#  'coihaique',
#  'hasaki',
#  'hervey bay',
#  'sadon',
#  'tokur',
#  'bonthe',
#  'bengkulu',
#  'scottsburgh',
#  'ketchikan',
#  'deputatskiy',
#  'bambous virieux',
#  'hilo',
#  'ahipara',
#  'amderma',
#  'vila franca do campo',
#  'avarua',
#  'illoqqortoormiut',
#  'ilulissat',
#  'nizhnekamsk',
#  'rawson',
#  'kamenka',
#  'barentsburg',
#  'atar',
#  'longjiang',
#  'teguldet',
#  'namatanai',
#  'araouane',
#  'pskov',
#  'natal',
#  'mar del plata',
#  'kizema',
#  'manggar',
#  'kruisfontein',
#  'newport',
#  'madimba',
#  'menongue',
#  'souillac',
#  'kabanjahe',
#  'siocon',
#  'kathmandu',
#  'aviles',
#  'la sarre',
#  'tocopilla',
#  'owensboro',
#  'sitka',
#  'tasiilaq',
#  'bethel',
#  'honolulu',
#  'namibe',
#  'boyuibe',
#  'ushtobe',
#  'zhangye',
#  'trelew',
#  'cherskiy',
#  'ancud',
#  'otautau',
#  'port elizabeth',
#  'borogontsy',
#  'keti bandar',
#  'lavrentiya',
#  'antibes',
#  'faanui',
#  'nichinan',
#  'alice springs',
#  'jamalpur',
#  'te anau',
#  'mayor pablo lagerenza',
#  'nijar',
#  'derzhavinsk',
#  'puerto carreno',
#  'makakilo city',
#  'tunduru',
#  'preobrazheniye',
#  'fort nelson',
#  'saldanha',
#  'carbonia',
#  'bjornevatn',
#  'sorland',
#  'hithadhoo',
#  'cabo san lucas',
#  'esperance',
#  'kawalu',
#  'khor',
#  'santa rosa',
#  'marsh harbour',
#  'san quintin',
#  'alyangula',
#  'rorvik',
#  'yarada',
#  'beringovskiy',
#  'husavik',
#  'warqla',
#  'san felipe',
#  'pacific grove',
#  'dzaoudzi',
#  'sturgis',
#  'caohai',
#  'tarko-sale',
#  'sao gabriel da cachoeira',
#  'barcelona',
#  'newton',
#  'katsuura',
#  'east london',
#  'polyarnyy',
#  'cabra',
#  'axim',
#  'moultrie',
#  'jalingo',
#  'sakaiminato',
#  'bilma',
#  'hami',
#  'vestmannaeyjar',
#  'tymovskoye',
#  'wajir',
#  'gat',
#  'anadyr',
#  'tura',
#  'elmira',
#  'sao filipe',
#  'zhanaozen',
#  'isangel',
#  'vaitupu',
#  'praia',
#  'sierre',
#  'college',
#  'ballina',
#  'kingussie',
#  'mehran',
#  'narsaq',
#  'olonets',
#  'sinkat',
#  'kemijarvi',
#  'khatanga',
#  'sinnamary',
#  'waddan',
#  'zolotinka',
#  'cape town',
#  'kutum',
#  'ribeira grande',
#  'sioux lookout',
#  'dikson',
#  'koslan',
#  'talakan',
#  'tautira',
#  'ridgecrest',
#  'hokitika',
#  'kharagauli',
#  'moron',
#  'nkhotakota',
#  'kaeo',
#  'ostrovnoy',
#  'novaya igirma',
#  'balkanabat',
#  'ivanteyevka',
#  'brae',
#  'ternate',
#  'villa rica',
#  'bumba',
#  'chalchihuites',
#  'buchanan',
#  'palabuhanratu',
#  'falkoping',
#  'henties bay',
#  'erice',
#  'stekolnyy',
#  'kikwit',
#  'orotukan',
#  'naze',
#  'athens',
#  'pavlodar',
#  'tumannyy',
#  'humberto de campos',
#  'noumea',
#  'san patricio',
#  'havoysund',
#  'torbay',
#  'colesberg',
#  'zimapan',
#  'kenai',
#  'freeport',
#  'tabiauea',
#  'pasni',
#  'samusu',
#  'aykhal',
#  'asau',
#  'saint-louis',
#  'mahebourg',
#  'laguna',
#  'geraldton',
#  'kimbe',
#  'berlevag',
#  'ozgon',
#  'pingxiang',
#  'surt',
#  'praya',
#  'cayenne',
#  'cidreira',
#  'yongzhou',
#  'sheboygan',
#  'tuatapere',
#  'nantucket',
#  'cairns',
#  'vao',
#  'khao yoi',
#  'vardo',
#  'black river',
#  'pangnirtung',
#  'havre-saint-pierre',
#  'grindavik',
#  'abalak',
#  'jaguey grande',
#  'pryazha',
#  'privolzhye',
#  'diffa',
#  'russell',
#  'sataua',
#  'chaihe',
#  'linxi',
#  'mahadday weyne',
#  'itarema',
#  'la orilla',
#  'ambilobe',
#  'marcona',
#  'southbridge',
#  'khonuu',
#  'champerico',
#  'kismayo',
#  'quatre cocos',
#  'walvis bay',
#  'lubumbashi',
#  'ciudad bolivar',
#  'dong hoi',
#  'tessalit',
#  'teya',
#  'hitoyoshi',
#  'taicheng',
#  'khoy',
#  'guerrero negro',
#  'zapolyarnyy',
#  'fortuna',
#  'bone',
#  'hovd',
#  'findlay',
#  'luau',
#  'kirakira',
#  'nizhneyansk',
#  'tiksi',
#  'sentyabrskiy',
#  'luderitz',
#  'ornskoldsvik',
#  'saint george',
#  'bolungarvik',
#  'antropovo',
#  'lorengau',
#  'loukhi',
#  'parkes',
#  'taman',
#  'kaitangata',
#  'altay',
#  'manzanillo',
#  'caceres',
#  'hay river',
#  'itahari',
#  'bardiyah',
#  'izumo',
#  'terrace',
#  'santa rosalia',
#  'dwarka',
#  'soubre',
#  'mayo',
#  'risor',
#  'port hedland',
#  'evensk',
#  'dabrowa gornicza',
#  'key west',
#  'north bend',
#  'liaocheng',
#  'haibowan',
#  'eyl',
#  'sembakung',
#  'novoagansk',
#  'hofn',
#  'kysyl-syr',
#  'santa maria',
#  'santa isabel do rio negro',
#  'teeli',
#  'rio gallegos',
#  'aflu',
#  'iqaluit',
#  'tombouctou',
#  'ituni',
#  'severo-kurilsk',
#  'marawi',
#  'victor harbor',
#  'kenora',
#  'rawah',
#  'la palma',
#  'lovozero',
#  'soure',
#  'nome',
#  'mirpur sakro',
#  'goundam',
#  'isla vista',
#  'attawapiskat',
#  'alice',
#  'shimoda',
#  'pevek',
#  'plettenberg bay',
#  'khandyga',
#  'teneguiban',
#  'general pico',
#  'hastings',
#  'marzuq',
#  'longyearbyen',
#  'aklavik',
#  'comodoro rivadavia',
#  'saint-francois',
#  'tsihombe',
#  'kaputa',
#  'cockburn town',
#  'san luis',
#  'nelson bay',
#  'haines junction',
#  'lunenburg',
#  'izvestkovyy',
#  'peniche',
#  'margate',
#  'venado tuerto',
#  'taksimo',
#  'coquimbo',
#  'fairbanks',
#  'rennes',
#  'umm kaddadah',
#  'pathum thani',
#  'sevilla',
#  'broken hill',
#  'touros',
#  'goderich',
#  'kropotkin',
#  'shingu',
#  'klaksvik',
#  'huarmey',
#  'buarcos',
#  'tortoli',
#  'ormara',
#  'louisbourg',
#  'arman',
#  'dire',
#  'pafos',
#  'moranbah',
#  'vostok',
#  'kodinsk',
#  'krasnyy oktyabr',
#  'meadow lake',
#  'mareeba',
#  'roebourne',
#  'dicabisagan',
#  'sao felix do xingu',
#  'aitape',
#  'shilong',
#  'galatista',
#  'vostochnyy',
#  'mao',
#  'jacareacanga',
#  'hamilton',
#  'vada',
#  'dzhusaly',
#  'kununurra',
#  'masjed-e soleyman',
#  'shirokiy',
#  'chikwawa',
#  'matara',
#  'samarai',
#  'nishihara',
#  'buritizeiro',
#  'gigmoto',
#  'tungor',
#  'razdolnoye',
#  'pouebo',
#  'swidwin',
#  'quthing',
#  'ballitoville',
#  'maniitsoq',
#  'shenjiamen',
#  'great yarmouth',
#  'darhan',
#  'kigorobya',
#  'xam nua',
#  'portland',
#  'chilca',
#  'juba',
#  'nguru',
#  'whitehorse',
#  'grand gaube',
#  'norman wells',
#  'oum hadjer',
#  'oeiras',
#  'tazovskiy',
#  'hohhot',
#  'krasnoselkup',
#  'pathein',
#  'dali',
#  'dingle',
#  'rantepao',
#  'lenggries',
#  'astorga',
#  'udachnyy',
#  'coari',
#  'kupang',
#  'acopiara',
#  'paamiut',
#  'lompoc',
#  'jinxiang',
#  'avera',
#  'north auburn',
#  'port macquarie',
#  'inuvik',
#  'chicama',
#  'ouadda',
#  'kurchum',
#  'sungaipenuh',
#  'teknaf',
#  'tigil',
#  'pavda',
#  'mehamn',
#  'harper',
#  'wamba',
#  'abbeville',
#  'saint anthony',
#  'mombaca',
#  'marystown',
#  'talcahuano',
#  'patratu',
#  'kattivakkam',
#  'ixtapa',
#  'santa isabel',
#  'puteyets',
#  'sambava',
#  'otane',
#  'kudahuvadhoo',
#  'barrhead',
#  'gornoye loo',
#  'sangar',
#  'karauzyak',
#  'altea',
#  'piryion',
#  'lerwick',
#  'bereda',
#  'itupiranga',
#  'obo',
#  'el faiyum',
#  'staryy biser',
#  'shimizu',
#  'loandjili',
#  'amapa',
#  'kargopol',
#  'olafsvik',
#  'bundaberg',
#  'bathsheba',
#  'mangaratiba',
#  'harer',
#  'killin',
#  'tual',
#  'aybak',
#  'porto novo',
#  'brufut',
#  'hambantota',
#  'waingapu',
#  'colares',
#  'raudeberg',
#  'rawannawi',
#  'rincon',
#  'la ronge',
#  'alexandria',
#  'tondi',
#  'kjollefjord',
#  'skalistyy',
#  'florida',
#  'devonport',
#  'zyryanka',
#  'chumikan',
#  'deniliquin',
#  'jonesboro',
#  'salalah',
#  'ust-kuyga',
#  'san andres',
#  'kleck',
#  'padang',
#  'qasigiannguit',
#  'paarl',
#  'skibbereen',
#  'isla mujeres',
#  'khuzdar',
#  'pontes e lacerda',
#  'riyadh',
#  'jalu',
#  'camacupa',
#  'denpasar',
#  'formosa',
#  'conakry',
#  'luoyang',
#  'gasa',
#  'carlisle',
#  'clifton',
#  'san vicente',
#  'turbat',
#  'tabou',
#  'purpe',
#  'sayat',
#  'kuytun',
#  'rivadavia',
#  'sumbe',
#  'daru',
#  'karlskrona',
#  'ritchie',
#  'mount isa',
#  'saraza',
#  'ust-nera',
#  'podbelsk',
#  'wajima',
#  'masterton',
#  'pochutla',
#  'dharchula',
#  'biak',
#  'oktyabrskoye',
#  'halifax',
#  'viligili',
#  'tupik',
#  'canico',
#  'novoderevyankovskaya',
#  'sampit',
#  'khani',
#  'panama city',
#  'mastic beach',
#  'garmsar',
#  'qui nhon',
#  'sistranda',
#  'utiroa',
#  'qaqortoq',
#  'hogyesz',
#  'kabo',
#  'rundu',
#  'gijon',
#  'pangody',
#  'port hardy',
#  'bac lieu',
#  'ust-tsilma',
#  'tema',
#  'carberry',
#  'dnestrovsc',
#  'constitucion',
#  'vangaindrano',
#  'maxixe',
#  'camopi',
#  'bandrele',
#  'wanning',
#  'karonga',
#  'charters towers',
#  'erenhot',
#  'burkhala',
#  'tonantins',
#  'port augusta',
#  'guadalupe y calvo',
#  'sur',
#  'ambovombe',
#  'jumla',
#  'warrnambool',
#  'murupara',
#  'havre',
#  'maceio',
#  'pangkalanbuun',
#  'bela',
#  'hajnowka',
#  'oussouye',
#  'karkaralinsk',
#  'cukai',
#  'kunda',
#  'erzin',
#  'alta floresta',
#  'sobolevo',
#  'pozo colorado',
#  'bastia',
#  'half moon bay',
#  'amazar',
#  'acarau',
#  'richards bay',
#  'morondava',
#  'zhigansk',
#  'susuman',
#  'tucurui',
#  'wasilla',
#  'kalabo',
#  'rajmahal',
#  'miraflores',
#  'san cristobal',
#  'afikpo',
#  'caravelas',
#  'valparaiso',
#  'nguiu',
#  'belyy yar',
#  'barawe',
#  'tambo grande',
#  'olkhovka',
#  'viedma',
#  'lac du bonnet',
#  'harindanga',
#  'skjervoy',
#  'belmonte',
#  'tongsa',
#  'tiznit',
#  'orel-izumrud',
#  'swan river',
#  'fez',
#  'puerto del rosario',
#  'san jeronimo',
#  'tulun',
#  'hirara',
#  'hualmay',
#  'hun',
#  'yulara',
#  'coos bay',
#  'joshimath',
#  'svetlaya',
#  'zhitikara',
#  'alugan',
#  'dunnville',
#  'ko samui',
#  'yerbogachen',
#  'lusambo',
#  'los llanos de aridane',
#  'farsund',
#  'misratah',
#  'santiago',
#  'hushitai',
#  'chapais',
#  'yhu',
#  'sergeyevka',
#  'dudinka',
#  'yerofey pavlovich',
#  'faya',
#  'eureka',
#  'missoula',
#  'sale',
#  'arnprior',
#  'lagoa',
#  'flin flon',
#  'hobyo',
#  'burnie',
#  'meyungs',
#  'careiro da varzea',
#  'bambanglipuro',
#  'dutse',
#  'kambove',
#  'bystryy istok',
#  'qibili',
#  'qandala']

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print (url)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

#loop through cities in list
for i, city in enumerate(cities):
    
#group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    #create URL endpoint for city
    city_url = url + '&q=' + city.replace(" ","+")
    
#log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    # add 1 to record count
    record_count += 1
    
print(requests.get(city_url).json())

# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mercedes
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | torva
# Processing Record 4 of Set 1 | jiddah
# Processing Record 5 of Set 1 | pisco
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | srednekolymsk
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | iquique
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | mount gambier
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | colonelganj
# Processing Record 16 of Set 1 | sao joao da barra
# Processing Record 17 of Set 1 | gamba
# Processing Record 18 of Set 1 | umm lajj
# Processing Record 19 of Set 1 | kangaatsiaq
# Processing Record 20 of Set 1 | sao jose do belmonte
# Processing Record 21 of Set 1 | port lincoln
# Processing Record 22 of Set 1 | grand river south east
# Processing Record 23 of Set 1 | yuzhno-yeniseyskiy
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | melilla
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | nampula
# Processing Record 28 of Set 1 | victoria
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | jacqueville
# Processing Record 31 of Set 1 | baghdad
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | vila velha
# Processing Record 35 of Set 1 | chapayevka
# Processing Record 36 of Set 1 | lakeside
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | nhulunbuy
# Processing Record 39 of Set 1 | kavieng
# Processing Record 40 of Set 1 | lebu
# Processing Record 41 of Set 1 | rio grande
# Processing Record 42 of Set 1 | hoorn
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | de-kastri
# Processing Record 45 of Set 1 | tabulbah
# Processing Record 46 of Set 1 | pandan
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | saint-joseph
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | lekoni
# Processing Record 2 of Set 2 | tuktoyaktuk
# Processing Record 3 of Set 2 | liloan
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | lolua
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | salinas
# Processing Record 8 of Set 2 | nikolskoye
# Processing Record 9 of Set 2 | saint-philippe
# Processing Record 10 of Set 2 | le marin
# Processing Record 11 of Set 2 | taolanaro
# Processing Record 12 of Set 2 | the valley
# Processing Record 13 of Set 2 | svetlyy
# Processing Record 14 of Set 2 | beloha
# Processing Record 15 of Set 2 | longlac
# Processing Record 16 of Set 2 | umzimvubu
# Processing Record 17 of Set 2 | adrar
# Processing Record 18 of Set 2 | flinders
# Processing Record 19 of Set 2 | talnakh
# Processing Record 20 of Set 2 | mumbwa
# Processing Record 21 of Set 2 | new norfolk
# Processing Record 22 of Set 2 | tehuantepec
# Processing Record 23 of Set 2 | caninde
# Processing Record 24 of Set 2 | penzance
# Processing Record 25 of Set 2 | dubti
# Processing Record 26 of Set 2 | urucara
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | alofi
# Processing Record 29 of Set 2 | road town
# Processing Record 30 of Set 2 | tolaga bay
# Processing Record 31 of Set 2 | codrington
# Processing Record 32 of Set 2 | belushya guba
# Processing Record 33 of Set 2 | provideniya
# Processing Record 34 of Set 2 | puerto ayora
# Processing Record 35 of Set 2 | saint-pierre
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | leningradskiy
# Processing Record 38 of Set 2 | leua
# Processing Record 39 of Set 2 | yellowknife
# Processing Record 40 of Set 2 | oksfjord
# Processing Record 41 of Set 2 | batagay-alyta
# Processing Record 42 of Set 2 | sarangani
# Processing Record 43 of Set 2 | nicoya
# Processing Record 44 of Set 2 | kozhva
# Processing Record 45 of Set 2 | mys shmidta
# Processing Record 46 of Set 2 | arraial do cabo
# Processing Record 47 of Set 2 | pedernales
# Processing Record 48 of Set 2 | manicore
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | bluff
# Processing Record 2 of Set 3 | mashhad
# Processing Record 3 of Set 3 | busselton
# Processing Record 4 of Set 3 | gerash
# Processing Record 5 of Set 3 | bonavista
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | port blair
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | muros
# Processing Record 12 of Set 3 | sumbawa
# Processing Record 13 of Set 3 | baykit
# Processing Record 14 of Set 3 | palmer
# Processing Record 15 of Set 3 | saleaula
# Processing Record 16 of Set 3 | dubai
# Processing Record 17 of Set 3 | butaritari
# Processing Record 18 of Set 3 | albany
# Processing Record 19 of Set 3 | saskylakh
# Processing Record 20 of Set 3 | coihaique
# Processing Record 21 of Set 3 | hasaki
# Processing Record 22 of Set 3 | hervey bay
# Processing Record 23 of Set 3 | sadon
# Processing Record 24 of Set 3 | tokur
# Processing Record 25 of Set 3 | bonthe
# Processing Record 26 of Set 3 | bengkulu
# Processing Record 27 of Set 3 | scottsburgh
# Processing Record 28 of Set 3 | ketchikan
# Processing Record 29 of Set 3 | deputatskiy
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | ahipara
# Processing Record 33 of Set 3 | amderma
# Processing Record 34 of Set 3 | vila franca do campo
# Processing Record 35 of Set 3 | avarua
# Processing Record 36 of Set 3 | illoqqortoormiut
# Processing Record 37 of Set 3 | ilulissat
# Processing Record 38 of Set 3 | nizhnekamsk
# Processing Record 39 of Set 3 | rawson
# Processing Record 40 of Set 3 | kamenka
# Processing Record 41 of Set 3 | barentsburg
# Processing Record 42 of Set 3 | atar
# Processing Record 43 of Set 3 | longjiang
# Processing Record 44 of Set 3 | teguldet
# Processing Record 45 of Set 3 | namatanai
# Processing Record 46 of Set 3 | araouane
# Processing Record 47 of Set 3 | pskov
# Processing Record 48 of Set 3 | natal
# Processing Record 49 of Set 3 | mar del plata
# Processing Record 50 of Set 3 | kizema
# Processing Record 1 of Set 4 | manggar
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | newport
# Processing Record 4 of Set 4 | madimba
# Processing Record 5 of Set 4 | menongue
# Processing Record 6 of Set 4 | souillac
# Processing Record 7 of Set 4 | kabanjahe
# Processing Record 8 of Set 4 | siocon
# Processing Record 9 of Set 4 | kathmandu
# Processing Record 10 of Set 4 | aviles
# Processing Record 11 of Set 4 | la sarre
# Processing Record 12 of Set 4 | tocopilla
# Processing Record 13 of Set 4 | owensboro
# Processing Record 14 of Set 4 | sitka
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | bethel
# Processing Record 17 of Set 4 | honolulu
# Processing Record 18 of Set 4 | namibe
# Processing Record 19 of Set 4 | boyuibe
# Processing Record 20 of Set 4 | ushtobe
# Processing Record 21 of Set 4 | zhangye
# Processing Record 22 of Set 4 | trelew
# Processing Record 23 of Set 4 | cherskiy
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | otautau
# Processing Record 26 of Set 4 | port elizabeth
# Processing Record 27 of Set 4 | borogontsy
# Processing Record 28 of Set 4 | keti bandar
# Processing Record 29 of Set 4 | lavrentiya
# Processing Record 30 of Set 4 | antibes
# Processing Record 31 of Set 4 | faanui
# Processing Record 32 of Set 4 | nichinan
# Processing Record 33 of Set 4 | alice springs
# Processing Record 34 of Set 4 | jamalpur
# Processing Record 35 of Set 4 | te anau
# Processing Record 36 of Set 4 | mayor pablo lagerenza
# Processing Record 37 of Set 4 | nijar
# Processing Record 38 of Set 4 | derzhavinsk
# Processing Record 39 of Set 4 | puerto carreno
# Processing Record 40 of Set 4 | makakilo city
# Processing Record 41 of Set 4 | tunduru
# Processing Record 42 of Set 4 | preobrazheniye
# Processing Record 43 of Set 4 | fort nelson
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | carbonia
# Processing Record 46 of Set 4 | bjornevatn
# Processing Record 47 of Set 4 | sorland
# Processing Record 48 of Set 4 | hithadhoo
# Processing Record 49 of Set 4 | cabo san lucas
# Processing Record 50 of Set 4 | esperance
# Processing Record 1 of Set 5 | kawalu
# Processing Record 2 of Set 5 | khor
# Processing Record 3 of Set 5 | santa rosa
# Processing Record 4 of Set 5 | marsh harbour
# Processing Record 5 of Set 5 | san quintin
# Processing Record 6 of Set 5 | alyangula
# Processing Record 7 of Set 5 | rorvik
# Processing Record 8 of Set 5 | yarada
# Processing Record 9 of Set 5 | beringovskiy
# Processing Record 10 of Set 5 | husavik
# Processing Record 11 of Set 5 | warqla
# Processing Record 12 of Set 5 | san felipe
# Processing Record 13 of Set 5 | pacific grove
# Processing Record 14 of Set 5 | dzaoudzi
# Processing Record 15 of Set 5 | sturgis
# Processing Record 16 of Set 5 | caohai
# Processing Record 17 of Set 5 | tarko-sale
# Processing Record 18 of Set 5 | sao gabriel da cachoeira
# Processing Record 19 of Set 5 | barcelona
# Processing Record 20 of Set 5 | newton
# Processing Record 21 of Set 5 | katsuura
# Processing Record 22 of Set 5 | east london
# Processing Record 23 of Set 5 | polyarnyy
# Processing Record 24 of Set 5 | cabra
# Processing Record 25 of Set 5 | axim
# Processing Record 26 of Set 5 | moultrie
# Processing Record 27 of Set 5 | jalingo
# Processing Record 28 of Set 5 | sakaiminato
# Processing Record 29 of Set 5 | bilma
# Processing Record 30 of Set 5 | hami
# Processing Record 31 of Set 5 | vestmannaeyjar
# Processing Record 32 of Set 5 | tymovskoye
# Processing Record 33 of Set 5 | wajir
# Processing Record 34 of Set 5 | gat
# Processing Record 35 of Set 5 | anadyr
# Processing Record 36 of Set 5 | tura
# Processing Record 37 of Set 5 | elmira
# Processing Record 38 of Set 5 | sao filipe
# Processing Record 39 of Set 5 | zhanaozen
# Processing Record 40 of Set 5 | isangel
# Processing Record 41 of Set 5 | vaitupu
# Processing Record 42 of Set 5 | praia
# Processing Record 43 of Set 5 | sierre
# Processing Record 44 of Set 5 | college
# Processing Record 45 of Set 5 | ballina
# Processing Record 46 of Set 5 | kingussie
# Processing Record 47 of Set 5 | mehran
# Processing Record 48 of Set 5 | narsaq
# Processing Record 49 of Set 5 | olonets
# Processing Record 50 of Set 5 | sinkat
# Processing Record 1 of Set 6 | kemijarvi
# Processing Record 2 of Set 6 | khatanga
# Processing Record 3 of Set 6 | sinnamary
# Processing Record 4 of Set 6 | waddan
# Processing Record 5 of Set 6 | zolotinka
# Processing Record 6 of Set 6 | cape town
# Processing Record 7 of Set 6 | kutum
# Processing Record 8 of Set 6 | ribeira grande
# Processing Record 9 of Set 6 | sioux lookout
# Processing Record 10 of Set 6 | dikson
# Processing Record 11 of Set 6 | koslan
# Processing Record 12 of Set 6 | talakan
# Processing Record 13 of Set 6 | tautira
# Processing Record 14 of Set 6 | ridgecrest
# Processing Record 15 of Set 6 | hokitika
# Processing Record 16 of Set 6 | kharagauli
# Processing Record 17 of Set 6 | moron
# Processing Record 18 of Set 6 | nkhotakota
# Processing Record 19 of Set 6 | kaeo
# Processing Record 20 of Set 6 | ostrovnoy
# Processing Record 21 of Set 6 | novaya igirma
# Processing Record 22 of Set 6 | balkanabat
# Processing Record 23 of Set 6 | ivanteyevka
# Processing Record 24 of Set 6 | brae
# Processing Record 25 of Set 6 | ternate
# Processing Record 26 of Set 6 | villa rica
# Processing Record 27 of Set 6 | bumba
# Processing Record 28 of Set 6 | chalchihuites
# Processing Record 29 of Set 6 | buchanan
# Processing Record 30 of Set 6 | palabuhanratu
# Processing Record 31 of Set 6 | falkoping
# Processing Record 32 of Set 6 | henties bay
# Processing Record 33 of Set 6 | erice
# Processing Record 34 of Set 6 | stekolnyy
# Processing Record 35 of Set 6 | kikwit
# Processing Record 36 of Set 6 | orotukan
# Processing Record 37 of Set 6 | naze
# Processing Record 38 of Set 6 | athens
# Processing Record 39 of Set 6 | pavlodar
# Processing Record 40 of Set 6 | tumannyy
# Processing Record 41 of Set 6 | humberto de campos
# Processing Record 42 of Set 6 | noumea
# Processing Record 43 of Set 6 | san patricio
# Processing Record 44 of Set 6 | havoysund
# Processing Record 45 of Set 6 | torbay
# Processing Record 46 of Set 6 | colesberg
# Processing Record 47 of Set 6 | zimapan
# Processing Record 48 of Set 6 | kenai
# Processing Record 49 of Set 6 | freeport
# Processing Record 50 of Set 6 | tabiauea
# Processing Record 1 of Set 7 | pasni
# Processing Record 2 of Set 7 | samusu
# Processing Record 3 of Set 7 | aykhal
# Processing Record 4 of Set 7 | asau
# Processing Record 5 of Set 7 | saint-louis
# Processing Record 6 of Set 7 | mahebourg
# Processing Record 7 of Set 7 | laguna
# Processing Record 8 of Set 7 | geraldton
# Processing Record 9 of Set 7 | kimbe
# Processing Record 10 of Set 7 | berlevag
# Processing Record 11 of Set 7 | ozgon
# Processing Record 12 of Set 7 | pingxiang
# Processing Record 13 of Set 7 | surt
# Processing Record 14 of Set 7 | praya
# Processing Record 15 of Set 7 | cayenne
# Processing Record 16 of Set 7 | cidreira
# Processing Record 17 of Set 7 | yongzhou
# Processing Record 18 of Set 7 | sheboygan
# Processing Record 19 of Set 7 | tuatapere
# Processing Record 20 of Set 7 | nantucket
# Processing Record 21 of Set 7 | cairns
# Processing Record 22 of Set 7 | vao
# Processing Record 23 of Set 7 | khao yoi
# Processing Record 24 of Set 7 | vardo
# Processing Record 25 of Set 7 | black river
# Processing Record 26 of Set 7 | pangnirtung
# Processing Record 27 of Set 7 | havre-saint-pierre
# Processing Record 28 of Set 7 | grindavik
# Processing Record 29 of Set 7 | abalak
# Processing Record 30 of Set 7 | jaguey grande
# Processing Record 31 of Set 7 | pryazha
# Processing Record 32 of Set 7 | privolzhye
# Processing Record 33 of Set 7 | diffa
# Processing Record 34 of Set 7 | russell
# Processing Record 35 of Set 7 | sataua
# Processing Record 36 of Set 7 | chaihe
# Processing Record 37 of Set 7 | linxi
# Processing Record 38 of Set 7 | mahadday weyne
# Processing Record 39 of Set 7 | itarema
# Processing Record 40 of Set 7 | la orilla
# Processing Record 41 of Set 7 | ambilobe
# Processing Record 42 of Set 7 | marcona
# Processing Record 43 of Set 7 | southbridge
# Processing Record 44 of Set 7 | khonuu
# Processing Record 45 of Set 7 | champerico
# Processing Record 46 of Set 7 | kismayo
# Processing Record 47 of Set 7 | quatre cocos
# Processing Record 48 of Set 7 | walvis bay
# Processing Record 49 of Set 7 | lubumbashi
# Processing Record 50 of Set 7 | ciudad bolivar
# Processing Record 1 of Set 8 | dong hoi
# Processing Record 2 of Set 8 | tessalit
# Processing Record 3 of Set 8 | teya
# Processing Record 4 of Set 8 | hitoyoshi
# Processing Record 5 of Set 8 | taicheng
# Processing Record 6 of Set 8 | khoy
# Processing Record 7 of Set 8 | guerrero negro
# Processing Record 8 of Set 8 | zapolyarnyy
# Processing Record 9 of Set 8 | fortuna
# Processing Record 10 of Set 8 | bone
# Processing Record 11 of Set 8 | hovd
# Processing Record 12 of Set 8 | findlay
# Processing Record 13 of Set 8 | luau
# Processing Record 14 of Set 8 | kirakira
# Processing Record 15 of Set 8 | nizhneyansk
# Processing Record 16 of Set 8 | tiksi
# Processing Record 17 of Set 8 | sentyabrskiy
# Processing Record 18 of Set 8 | luderitz
# Processing Record 19 of Set 8 | ornskoldsvik
# Processing Record 20 of Set 8 | saint george
# Processing Record 21 of Set 8 | bolungarvik
# Processing Record 22 of Set 8 | antropovo
# Processing Record 23 of Set 8 | lorengau
# Processing Record 24 of Set 8 | loukhi
# Processing Record 25 of Set 8 | parkes
# Processing Record 26 of Set 8 | taman
# Processing Record 27 of Set 8 | kaitangata
# Processing Record 28 of Set 8 | altay
# Processing Record 29 of Set 8 | manzanillo
# Processing Record 30 of Set 8 | caceres
# Processing Record 31 of Set 8 | hay river
# Processing Record 32 of Set 8 | itahari
# Processing Record 33 of Set 8 | bardiyah
# Processing Record 34 of Set 8 | izumo
# Processing Record 35 of Set 8 | terrace
# Processing Record 36 of Set 8 | santa rosalia
# Processing Record 37 of Set 8 | dwarka
# Processing Record 38 of Set 8 | soubre
# Processing Record 39 of Set 8 | mayo
# Processing Record 40 of Set 8 | risor
# Processing Record 41 of Set 8 | port hedland
# Processing Record 42 of Set 8 | evensk
# Processing Record 43 of Set 8 | dabrowa gornicza
# Processing Record 44 of Set 8 | key west
# Processing Record 45 of Set 8 | north bend
# Processing Record 46 of Set 8 | liaocheng
# Processing Record 47 of Set 8 | haibowan
# Processing Record 48 of Set 8 | eyl
# Processing Record 49 of Set 8 | sembakung
# Processing Record 50 of Set 8 | novoagansk
# Processing Record 1 of Set 9 | hofn
# Processing Record 2 of Set 9 | kysyl-syr
# Processing Record 3 of Set 9 | santa maria
# Processing Record 4 of Set 9 | santa isabel do rio negro
# Processing Record 5 of Set 9 | teeli
# Processing Record 6 of Set 9 | rio gallegos
# Processing Record 7 of Set 9 | aflu
# Processing Record 8 of Set 9 | iqaluit
# Processing Record 9 of Set 9 | tombouctou
# Processing Record 10 of Set 9 | ituni
# Processing Record 11 of Set 9 | severo-kurilsk
# Processing Record 12 of Set 9 | marawi
# Processing Record 13 of Set 9 | victor harbor
# Processing Record 14 of Set 9 | kenora
# Processing Record 15 of Set 9 | rawah
# Processing Record 16 of Set 9 | la palma
# Processing Record 17 of Set 9 | lovozero
# Processing Record 18 of Set 9 | soure
# Processing Record 19 of Set 9 | nome
# Processing Record 20 of Set 9 | mirpur sakro
# Processing Record 21 of Set 9 | goundam
# Processing Record 22 of Set 9 | isla vista
# Processing Record 23 of Set 9 | attawapiskat
# Processing Record 24 of Set 9 | alice
# Processing Record 25 of Set 9 | shimoda
# Processing Record 26 of Set 9 | pevek
# Processing Record 27 of Set 9 | plettenberg bay
# Processing Record 28 of Set 9 | khandyga
# Processing Record 29 of Set 9 | teneguiban
# Processing Record 30 of Set 9 | general pico
# Processing Record 31 of Set 9 | hastings
# Processing Record 32 of Set 9 | marzuq
# Processing Record 33 of Set 9 | longyearbyen
# Processing Record 34 of Set 9 | aklavik
# Processing Record 35 of Set 9 | comodoro rivadavia
# Processing Record 36 of Set 9 | saint-francois
# Processing Record 37 of Set 9 | tsihombe
# Processing Record 38 of Set 9 | kaputa
# Processing Record 39 of Set 9 | cockburn town
# Processing Record 40 of Set 9 | san luis
# Processing Record 41 of Set 9 | nelson bay
# Processing Record 42 of Set 9 | haines junction
# Processing Record 43 of Set 9 | lunenburg
# Processing Record 44 of Set 9 | izvestkovyy
# Processing Record 45 of Set 9 | peniche
# Processing Record 46 of Set 9 | margate
# Processing Record 47 of Set 9 | venado tuerto
# Processing Record 48 of Set 9 | taksimo
# Processing Record 49 of Set 9 | coquimbo
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | rennes
# Processing Record 2 of Set 10 | umm kaddadah
# Processing Record 3 of Set 10 | pathum thani
# Processing Record 4 of Set 10 | sevilla
# Processing Record 5 of Set 10 | broken hill
# Processing Record 6 of Set 10 | touros
# Processing Record 7 of Set 10 | goderich
# Processing Record 8 of Set 10 | kropotkin
# Processing Record 9 of Set 10 | shingu
# Processing Record 10 of Set 10 | klaksvik
# Processing Record 11 of Set 10 | huarmey
# Processing Record 12 of Set 10 | buarcos
# Processing Record 13 of Set 10 | tortoli
# Processing Record 14 of Set 10 | ormara
# Processing Record 15 of Set 10 | louisbourg
# Processing Record 16 of Set 10 | arman
# Processing Record 17 of Set 10 | dire
# Processing Record 18 of Set 10 | pafos
# Processing Record 19 of Set 10 | moranbah
# Processing Record 20 of Set 10 | vostok
# Processing Record 21 of Set 10 | kodinsk
# Processing Record 22 of Set 10 | krasnyy oktyabr
# Processing Record 23 of Set 10 | meadow lake
# Processing Record 24 of Set 10 | mareeba
# Processing Record 25 of Set 10 | roebourne
# Processing Record 26 of Set 10 | dicabisagan
# Processing Record 27 of Set 10 | sao felix do xingu
# Processing Record 28 of Set 10 | aitape
# Processing Record 29 of Set 10 | shilong
# Processing Record 30 of Set 10 | galatista
# Processing Record 31 of Set 10 | vostochnyy
# Processing Record 32 of Set 10 | mao
# Processing Record 33 of Set 10 | jacareacanga
# Processing Record 34 of Set 10 | hamilton
# Processing Record 35 of Set 10 | vada
# Processing Record 36 of Set 10 | dzhusaly
# Processing Record 37 of Set 10 | kununurra
# Processing Record 38 of Set 10 | masjed-e soleyman
# Processing Record 39 of Set 10 | shirokiy
# Processing Record 40 of Set 10 | chikwawa
# Processing Record 41 of Set 10 | matara
# Processing Record 42 of Set 10 | samarai
# Processing Record 43 of Set 10 | nishihara
# Processing Record 44 of Set 10 | buritizeiro
# Processing Record 45 of Set 10 | gigmoto
# Processing Record 46 of Set 10 | tungor
# Processing Record 47 of Set 10 | razdolnoye
# Processing Record 48 of Set 10 | pouebo
# Processing Record 49 of Set 10 | swidwin
# Processing Record 50 of Set 10 | quthing
# Processing Record 1 of Set 11 | ballitoville
# Processing Record 2 of Set 11 | maniitsoq
# Processing Record 3 of Set 11 | shenjiamen
# Processing Record 4 of Set 11 | great yarmouth
# Processing Record 5 of Set 11 | darhan
# Processing Record 6 of Set 11 | kigorobya
# Processing Record 7 of Set 11 | xam nua
# Processing Record 8 of Set 11 | portland
# Processing Record 9 of Set 11 | chilca
# Processing Record 10 of Set 11 | juba
# Processing Record 11 of Set 11 | nguru
# Processing Record 12 of Set 11 | whitehorse
# Processing Record 13 of Set 11 | grand gaube
# Processing Record 14 of Set 11 | norman wells
# Processing Record 15 of Set 11 | oum hadjer
# Processing Record 16 of Set 11 | oeiras
# Processing Record 17 of Set 11 | tazovskiy
# Processing Record 18 of Set 11 | hohhot
# Processing Record 19 of Set 11 | krasnoselkup
# Processing Record 20 of Set 11 | pathein
# Processing Record 21 of Set 11 | dali
# Processing Record 22 of Set 11 | dingle
# Processing Record 23 of Set 11 | rantepao
# Processing Record 24 of Set 11 | lenggries
# Processing Record 25 of Set 11 | astorga
# Processing Record 26 of Set 11 | udachnyy
# Processing Record 27 of Set 11 | coari
# Processing Record 28 of Set 11 | kupang
# Processing Record 29 of Set 11 | acopiara
# Processing Record 30 of Set 11 | paamiut
# Processing Record 31 of Set 11 | lompoc
# Processing Record 32 of Set 11 | jinxiang
# Processing Record 33 of Set 11 | avera
# Processing Record 34 of Set 11 | north auburn
# Processing Record 35 of Set 11 | port macquarie
# Processing Record 36 of Set 11 | inuvik
# Processing Record 37 of Set 11 | chicama
# Processing Record 38 of Set 11 | ouadda
# Processing Record 39 of Set 11 | kurchum
# Processing Record 40 of Set 11 | sungaipenuh
# Processing Record 41 of Set 11 | teknaf
# Processing Record 42 of Set 11 | tigil
# Processing Record 43 of Set 11 | pavda
# Processing Record 44 of Set 11 | mehamn
# Processing Record 45 of Set 11 | harper
# Processing Record 46 of Set 11 | wamba
# Processing Record 47 of Set 11 | abbeville
# Processing Record 48 of Set 11 | saint anthony
# Processing Record 49 of Set 11 | mombaca
# Processing Record 50 of Set 11 | marystown
# Processing Record 1 of Set 12 | talcahuano
# Processing Record 2 of Set 12 | patratu
# Processing Record 3 of Set 12 | kattivakkam
# Processing Record 4 of Set 12 | ixtapa
# Processing Record 5 of Set 12 | santa isabel
# Processing Record 6 of Set 12 | puteyets
# Processing Record 7 of Set 12 | sambava
# Processing Record 8 of Set 12 | otane
# Processing Record 9 of Set 12 | kudahuvadhoo
# Processing Record 10 of Set 12 | barrhead
# Processing Record 11 of Set 12 | gornoye loo
# Processing Record 12 of Set 12 | sangar
# Processing Record 13 of Set 12 | karauzyak
# Processing Record 14 of Set 12 | altea
# Processing Record 15 of Set 12 | piryion
# Processing Record 16 of Set 12 | lerwick
# Processing Record 17 of Set 12 | bereda
# Processing Record 18 of Set 12 | itupiranga
# Processing Record 19 of Set 12 | obo
# Processing Record 20 of Set 12 | el faiyum
# Processing Record 21 of Set 12 | staryy biser
# Processing Record 22 of Set 12 | shimizu
# Processing Record 23 of Set 12 | loandjili
# Processing Record 24 of Set 12 | amapa
# Processing Record 25 of Set 12 | kargopol
# Processing Record 26 of Set 12 | olafsvik
# Processing Record 27 of Set 12 | bundaberg
# Processing Record 28 of Set 12 | bathsheba
# Processing Record 29 of Set 12 | mangaratiba
# Processing Record 30 of Set 12 | harer
# Processing Record 31 of Set 12 | killin
# Processing Record 32 of Set 12 | tual
# Processing Record 33 of Set 12 | aybak
# Processing Record 34 of Set 12 | porto novo
# Processing Record 35 of Set 12 | brufut
# Processing Record 36 of Set 12 | hambantota
# Processing Record 37 of Set 12 | waingapu
# Processing Record 38 of Set 12 | colares
# Processing Record 39 of Set 12 | raudeberg
# Processing Record 40 of Set 12 | rawannawi
# Processing Record 41 of Set 12 | rincon
# Processing Record 42 of Set 12 | la ronge
# Processing Record 43 of Set 12 | alexandria
# Processing Record 44 of Set 12 | tondi
# Processing Record 45 of Set 12 | kjollefjord
# Processing Record 46 of Set 12 | skalistyy
# Processing Record 47 of Set 12 | florida
# Processing Record 48 of Set 12 | devonport
# Processing Record 49 of Set 12 | zyryanka
# Processing Record 50 of Set 12 | chumikan
# Processing Record 1 of Set 13 | deniliquin
# Processing Record 2 of Set 13 | jonesboro
# Processing Record 3 of Set 13 | salalah
# Processing Record 4 of Set 13 | ust-kuyga
# Processing Record 5 of Set 13 | san andres
# Processing Record 6 of Set 13 | kleck
# Processing Record 7 of Set 13 | padang
# Processing Record 8 of Set 13 | qasigiannguit
# Processing Record 9 of Set 13 | paarl
# Processing Record 10 of Set 13 | skibbereen
# Processing Record 11 of Set 13 | isla mujeres
# Processing Record 12 of Set 13 | khuzdar
# Processing Record 13 of Set 13 | pontes e lacerda
# Processing Record 14 of Set 13 | riyadh
# Processing Record 15 of Set 13 | jalu
# Processing Record 16 of Set 13 | camacupa
# Processing Record 17 of Set 13 | denpasar
# Processing Record 18 of Set 13 | formosa
# Processing Record 19 of Set 13 | conakry
# Processing Record 20 of Set 13 | luoyang
# Processing Record 21 of Set 13 | gasa
# Processing Record 22 of Set 13 | carlisle
# Processing Record 23 of Set 13 | clifton
# Processing Record 24 of Set 13 | san vicente
# Processing Record 25 of Set 13 | turbat
# Processing Record 26 of Set 13 | tabou
# Processing Record 27 of Set 13 | purpe
# Processing Record 28 of Set 13 | sayat
# Processing Record 29 of Set 13 | kuytun
# Processing Record 30 of Set 13 | rivadavia
# Processing Record 31 of Set 13 | sumbe
# Processing Record 32 of Set 13 | daru
# Processing Record 33 of Set 13 | karlskrona
# Processing Record 34 of Set 13 | ritchie
# Processing Record 35 of Set 13 | mount isa
# Processing Record 36 of Set 13 | saraza
# Processing Record 37 of Set 13 | ust-nera
# Processing Record 38 of Set 13 | podbelsk
# Processing Record 39 of Set 13 | wajima
# Processing Record 40 of Set 13 | masterton
# Processing Record 41 of Set 13 | pochutla
# Processing Record 42 of Set 13 | dharchula
# Processing Record 43 of Set 13 | biak
# Processing Record 44 of Set 13 | oktyabrskoye
# Processing Record 45 of Set 13 | halifax
# Processing Record 46 of Set 13 | viligili
# Processing Record 47 of Set 13 | tupik
# Processing Record 48 of Set 13 | canico
# Processing Record 49 of Set 13 | novoderevyankovskaya
# Processing Record 50 of Set 13 | sampit
# Processing Record 1 of Set 14 | khani
# Processing Record 2 of Set 14 | panama city
# Processing Record 3 of Set 14 | mastic beach
# Processing Record 4 of Set 14 | garmsar
# Processing Record 5 of Set 14 | qui nhon
# Processing Record 6 of Set 14 | sistranda
# Processing Record 7 of Set 14 | utiroa
# Processing Record 8 of Set 14 | qaqortoq
# Processing Record 9 of Set 14 | hogyesz
# Processing Record 10 of Set 14 | kabo
# Processing Record 11 of Set 14 | rundu
# Processing Record 12 of Set 14 | gijon
# Processing Record 13 of Set 14 | pangody
# Processing Record 14 of Set 14 | port hardy
# Processing Record 15 of Set 14 | bac lieu
# Processing Record 16 of Set 14 | ust-tsilma
# Processing Record 17 of Set 14 | tema
# Processing Record 18 of Set 14 | carberry
# Processing Record 19 of Set 14 | dnestrovsc
# Processing Record 20 of Set 14 | constitucion
# Processing Record 21 of Set 14 | vangaindrano
# Processing Record 22 of Set 14 | maxixe
# Processing Record 23 of Set 14 | camopi
# Processing Record 24 of Set 14 | bandrele
# Processing Record 25 of Set 14 | wanning
# Processing Record 26 of Set 14 | karonga
# Processing Record 27 of Set 14 | charters towers
# Processing Record 28 of Set 14 | erenhot
# Processing Record 29 of Set 14 | burkhala
# Processing Record 30 of Set 14 | tonantins
# Processing Record 31 of Set 14 | port augusta
# Processing Record 32 of Set 14 | guadalupe y calvo
# Processing Record 33 of Set 14 | sur
# Processing Record 34 of Set 14 | ambovombe
# Processing Record 35 of Set 14 | jumla
# Processing Record 36 of Set 14 | warrnambool
# Processing Record 37 of Set 14 | murupara
# Processing Record 38 of Set 14 | havre
# Processing Record 39 of Set 14 | maceio
# Processing Record 40 of Set 14 | pangkalanbuun
# Processing Record 41 of Set 14 | bela
# Processing Record 42 of Set 14 | hajnowka
# Processing Record 43 of Set 14 | oussouye
# Processing Record 44 of Set 14 | karkaralinsk
# Processing Record 45 of Set 14 | cukai
# Processing Record 46 of Set 14 | kunda
# Processing Record 47 of Set 14 | erzin
# Processing Record 48 of Set 14 | alta floresta
# Processing Record 49 of Set 14 | sobolevo
# Processing Record 50 of Set 14 | pozo colorado
# Processing Record 1 of Set 15 | bastia
# Processing Record 2 of Set 15 | half moon bay
# Processing Record 3 of Set 15 | amazar
# Processing Record 4 of Set 15 | acarau
# Processing Record 5 of Set 15 | richards bay
# Processing Record 6 of Set 15 | morondava
# Processing Record 7 of Set 15 | zhigansk
# Processing Record 8 of Set 15 | susuman
# Processing Record 9 of Set 15 | tucurui
# Processing Record 10 of Set 15 | wasilla
# Processing Record 11 of Set 15 | kalabo
# Processing Record 12 of Set 15 | rajmahal
# Processing Record 13 of Set 15 | miraflores
# Processing Record 14 of Set 15 | san cristobal
# Processing Record 15 of Set 15 | afikpo
# Processing Record 16 of Set 15 | caravelas
# Processing Record 17 of Set 15 | valparaiso
# Processing Record 18 of Set 15 | nguiu
# Processing Record 19 of Set 15 | belyy yar
# Processing Record 20 of Set 15 | barawe
# Processing Record 21 of Set 15 | tambo grande
# Processing Record 22 of Set 15 | olkhovka
# Processing Record 23 of Set 15 | viedma
# Processing Record 24 of Set 15 | lac du bonnet
# Processing Record 25 of Set 15 | harindanga
# Processing Record 26 of Set 15 | skjervoy
# Processing Record 27 of Set 15 | belmonte
# Processing Record 28 of Set 15 | tongsa
# Processing Record 29 of Set 15 | tiznit
# Processing Record 30 of Set 15 | orel-izumrud
# Processing Record 31 of Set 15 | swan river
# Processing Record 32 of Set 15 | fez
# Processing Record 33 of Set 15 | puerto del rosario
# Processing Record 34 of Set 15 | san jeronimo
# Processing Record 35 of Set 15 | tulun
# Processing Record 36 of Set 15 | hirara
# Processing Record 37 of Set 15 | hualmay
# Processing Record 38 of Set 15 | hun
# Processing Record 39 of Set 15 | yulara
# Processing Record 40 of Set 15 | coos bay
# Processing Record 41 of Set 15 | joshimath
# Processing Record 42 of Set 15 | svetlaya
# Processing Record 43 of Set 15 | zhitikara
# Processing Record 44 of Set 15 | alugan
# Processing Record 45 of Set 15 | dunnville
# Processing Record 46 of Set 15 | ko samui
# Processing Record 47 of Set 15 | yerbogachen
# Processing Record 48 of Set 15 | lusambo
# Processing Record 49 of Set 15 | los llanos de aridane
# Processing Record 50 of Set 15 | farsund
# Processing Record 1 of Set 16 | misratah
# Processing Record 2 of Set 16 | santiago
# Processing Record 3 of Set 16 | hushitai
# Processing Record 4 of Set 16 | chapais
# Processing Record 5 of Set 16 | yhu
# Processing Record 6 of Set 16 | sergeyevka
# Processing Record 7 of Set 16 | dudinka
# Processing Record 8 of Set 16 | yerofey pavlovich
# Processing Record 9 of Set 16 | faya
# Processing Record 10 of Set 16 | eureka
# Processing Record 11 of Set 16 | missoula
# Processing Record 12 of Set 16 | sale
# Processing Record 13 of Set 16 | arnprior
# Processing Record 14 of Set 16 | lagoa
# Processing Record 15 of Set 16 | flin flon
# Processing Record 16 of Set 16 | hobyo
# Processing Record 17 of Set 16 | burnie
# Processing Record 18 of Set 16 | meyungs
# Processing Record 19 of Set 16 | careiro da varzea
# Processing Record 20 of Set 16 | bambanglipuro
# Processing Record 21 of Set 16 | dutse
# Processing Record 22 of Set 16 | kambove
# Processing Record 23 of Set 16 | bystryy istok
# Processing Record 24 of Set 16 | qibili
# Processing Record 25 of Set 16 | qandala
# {'coord': {'lon': 49.8728, 'lat': 11.472}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 89.1, 'feels_like': 94.66, 'temp_min': 89.1, 'temp_max': 89.1, 'pressure': 1005, 'humidity': 54, 'sea_level': 1005, 'grnd_level': 1004}, 'visibility': 10000, 'wind': {'speed': 4.25, 'deg': 212, 'gust': 18.37}, 'clouds': {'all': 57}, 'dt': 1658512235, 'sys': {'country': 'SO', 'sunrise': 1658456754, 'sunset': 1658502458}, 'timezone': 10800, 'id': 53157, 'name': 'Qandala', 'cod': 200}
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# []

# %%
# Recall that we can convert a list of dictionaries to a Pandas DataFrame using df = pd.DataFrame(list with dictionaries).
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
